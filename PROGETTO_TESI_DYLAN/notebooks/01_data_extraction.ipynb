# %% [markdown]
# # Data Extraction from Compressed CSV
#
# This notebook extracts data from the compressed `data.csv.gz` file and saves the processed data to the `data/processed` directory.

# %% [markdown]
# ## 1. Import Required Libraries

# %%
import pandas as pd
import os
from pathlib import Path

# %% [markdown]
# ## 2. Load Compressed CSV File
#
# Pandas automatically handles gzip compression when reading files with the `.gz` extension.

# %%
# Define the path to the compressed CSV file
FILE_NAME = 'data_13_17'
file_path = f'../data/raw/{FILE_NAME}.csv.gz'

# Read the compressed CSV file
df = pd.read_csv(file_path)

print(f"Data loaded successfully!")
print(f"Total rows: {len(df)}")
print(f"Total columns: {len(df.columns)}")

df.rename(columns={df.columns[0]: 'timestamp'}, inplace=True)
df['timestamp'] = pd.to_datetime(df['timestamp'],format='%Y-%m-%d')
# Out:
# Data loaded successfully!
# Total rows: 1259
# Total columns: 641

# %% [markdown]
# ## 3. Explore Data Structure
#
# Let's examine the first rows and get information about the dataset.

# %%
# Display first few rows
print("First 5 rows:")
print(df.head())
# Out:
# First 5 rows:
#    timestamp        BBY        GME  RF  LIFE       CSCO  REG        TSN  \
# 0 2013-02-28  14.313087  20.399103 NaN   NaN  17.893888  NaN  21.696400
# 1 2013-03-01  14.967250  19.800806 NaN   NaN  17.872437  NaN  22.184497
# 2 2013-03-04  15.499302  19.380913 NaN   NaN  17.795216  NaN  22.213208
# 3 2013-03-05  16.048799  20.006635 NaN   NaN  18.205347  NaN  22.328055
# 4 2013-03-06  16.354075  20.097200 NaN   NaN  18.631780  NaN  22.557748
#
#          TEG        KMI  ...        COH        MSI    RHT  TPR  SPGI  DXC  \
# 0  51.308858  30.784206  ...  41.309043  56.243199  50.81  NaN   NaN  NaN
# 1  50.882569  30.941988  ...  41.215023  56.080464  51.58  NaN   NaN  NaN
# 2  51.063969  31.174510  ...  42.121035  56.505384  52.08  NaN   NaN  NaN
# 3  51.816777  31.108075  ...  42.821913  56.930305  51.99  NaN   NaN  NaN
# 4  51.317928  30.701162  ...  42.933027  57.056877  52.80  NaN   NaN  NaN
#
#           DD        VMC  NWS  ULTA
# 0  40.617748  49.740070  NaN   NaN
# ...

# %%
# Get data info
print("\nDataset Info:")
df.info()
# Out:
# Dataset Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Columns: 641 entries, timestamp to ULTA
# dtypes: datetime64[us](1), float64(640)
# memory usage: 6.2 MB

# %%
# Get statistical summary
print("\nStatistical Summary:")
print(df.describe())
# Out:
# Statistical Summary:
#                         timestamp          BBY         GME          RF  LIFE  \
# count                        1259  1257.000000  798.000000  984.000000   0.0
# mean   2015-08-27 20:02:05.814138    36.326736   34.209938   11.089416   NaN
# min           2013-02-28 00:00:00    14.313087   19.380913    6.792908   NaN
# 25%           2014-05-29 12:00:00    28.330630   30.376785    9.066066   NaN
# 50%           2015-08-27 00:00:00    32.446978   34.652269    9.611882   NaN
# 75%           2016-11-24 00:00:00    41.946517   38.205282   14.011143   NaN
# max           2018-02-26 00:00:00    78.060000   48.067639   19.800000   NaN
# std                           NaN    12.493909    5.680991    2.981854   NaN
#
#               CSCO         REG          TSN         TEG          KMI  ...  \
# count  1257.000000  227.000000  1257.000000  588.000000  1257.000000  ...
# mean     26.144026   63.782035    48.989860   60.983585    26.290956  ...
# ...

# %% [markdown]
# ## 4. Save Processed Data
#
# Create the output directory if it doesn't exist and save the extracted data as CSV.

# %%
# Define the output directory
output_dir = Path('../data/processed')

# Create the directory if it doesn't exist
output_dir.mkdir(parents=True, exist_ok=True)

# Save the data as CSV
output_path = output_dir / f'{FILE_NAME}.csv'
df.to_csv(output_path, index=False)

print(f"Data saved to: {output_path}")
print(f"File size: {os.path.getsize(output_path) / (1024*1024):.2f} MB")
# Out:
# Data saved to: ..\data\processed\data_13_17.csv
# File size: 8.58 MB
