# %% [markdown]
# # Linear Autoencoder on Correlation Matrices
# In this notebook we train a linear autoencoder (no non-linear activations) on full correlation matrices, compress them into a latent space, reconstruct them, and evaluate reconstruction quality across different latent dimensions.

# %%
from pathlib import Path
import random
import warnings
import sys
import json

import numpy as np
import pandas as pd
import seaborn as sns
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt

np.set_printoptions(suppress=True, precision=4)
warnings.filterwarnings('ignore', message='.*Clustering large matrix.*')

# %% [markdown]
# ## Step 1: Load Train/Val/Test Splits
# Load correlation matrices from an existing dataset folder containing `train.pt`, `val.pt`, and `test.pt`.
# - Local PC: `data/processed/dataset/<DATASET_NAME>`
# - Google Colab: `dataset_tesi/<DATASET_NAME>`

# %%
DATASET_NAME = 'data_00_20_w724_s10'

if 'google.colab' in sys.modules:
    print('Ambiente rilevato: Google Colab')
    IS_COLAB = True
else:
    print('Ambiente rilevato: Locale (PC)')
    IS_COLAB = False

if IS_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')

    base_dir = Path('/content/drive/MyDrive/dataset_tesi')
else:
    project_root = Path.cwd().resolve().parent
    base_dir = project_root / 'data' / 'processed' / 'dataset'

dataset_dir = base_dir / DATASET_NAME

TRAIN_FILE = dataset_dir / 'train.pt'
VAL_FILE = dataset_dir / 'val.pt'
TEST_FILE = dataset_dir / 'test.pt'

for split_path in (TRAIN_FILE, VAL_FILE, TEST_FILE):
    if not split_path.exists():
        raise FileNotFoundError(
            f"Errore: Il file '{split_path.name}' non e stato trovato in: {dataset_dir.absolute()}"
        )

print(f'Dataset selezionato: {DATASET_NAME}')
print(f'Train: {TRAIN_FILE.name} | Val: {VAL_FILE.name} | Test: {TEST_FILE.name}')
# Out:
# Ambiente rilevato: Locale (PC)
# Dataset selezionato: data_00_20_w724_s10
# Train: train.pt | Val: val.pt | Test: test.pt

# %%
def load_corr_payload(pt_path: Path):
    payload = torch.load(pt_path, map_location='cpu')

    if isinstance(payload, dict):
        corr_tensor = payload.get('corr_tensor', None)
        meta = {k: v for k, v in payload.items() if k != 'corr_tensor'}
    elif isinstance(payload, torch.Tensor):
        corr_tensor = payload
        meta = {}
    else:
        raise TypeError(f'Unsupported .pt format: {type(payload)}')

    if corr_tensor is None:
        raise KeyError('corr_tensor key not found in .pt file')

    if corr_tensor.ndim != 3 or corr_tensor.shape[1] != corr_tensor.shape[2]:
        raise ValueError(f'Invalid shape for corr_tensor: {corr_tensor.shape}')

    return corr_tensor.float(), meta


train_corr, train_meta = load_corr_payload(TRAIN_FILE)
val_corr, val_meta = load_corr_payload(VAL_FILE)
test_corr, test_meta = load_corr_payload(TEST_FILE)

if train_corr.shape[1:] != test_corr.shape[1:]:
    raise ValueError(f'Train/test asset dims mismatch: {train_corr.shape} vs {test_corr.shape}')
if val_corr.shape[1:] != train_corr.shape[1:]:
    raise ValueError(f'Val/train asset dims mismatch: {val_corr.shape} vs {train_corr.shape}')

print(f'train_corr shape: {tuple(train_corr.shape)}')
print(f'val_corr shape:   {tuple(val_corr.shape)}')
print(f'test_corr shape:  {tuple(test_corr.shape)}')
# Out:
# train_corr shape: (289, 362, 362)
# val_corr shape:   (82, 362, 362)
# test_corr shape:  (41, 362, 362)

# %% [markdown]
# ## Step 2: Prepare Matrices from Existing Splits
# Use full correlation matrices as input. Each matrix is flattened to a vector of size `N x N`.
# Train/val/test come directly from the loaded split files (no random split in notebook).

# %%
train_np = train_corr.numpy().astype(np.float32)
val_np = val_corr.numpy().astype(np.float32)
test_np = test_corr.numpy().astype(np.float32)

n_train, n_assets, _ = train_np.shape
n_val = val_np.shape[0]
n_test = test_np.shape[0]
n_matrices = n_train + n_val + n_test
n_features = n_assets * n_assets

x_train = torch.from_numpy(train_np.reshape(n_train, n_features))
x_val = torch.from_numpy(val_np.reshape(n_val, n_features))
x_test = torch.from_numpy(test_np.reshape(n_test, n_features))

VAL_FRACTION = n_val / n_matrices
TEST_FRACTION = n_test / n_matrices

print(f'Number of matrices: {n_matrices}')
print(f'Matrix shape: ({n_assets}, {n_assets})')
print(f'Flattened input size: {n_features}')
print(f'Train size: {n_train} | Val size: {n_val} | Test size: {n_test}')
# Out:
# Number of matrices: 412
# Matrix shape: (362, 362)
# Flattened input size: 131044
# Train size: 289 | Val size: 82 | Test size: 41

# %% [markdown]
# ## Step 3: Define a Linear Autoencoder
# The encoder and decoder are pure linear layers (no activation functions).

# %%
class LinearAutoencoder(nn.Module):
    def __init__(self, input_dim: int, latent_dim: int):
        super().__init__()
        self.encoder = nn.Linear(input_dim, latent_dim)
        self.decoder = nn.Linear(latent_dim, input_dim)

    def forward(self, x: torch.Tensor):
        z = self.encoder(x)
        x_hat = self.decoder(z)
        return x_hat

# %% [markdown]
# ## Step 4: Training and Evaluation Utilities
# Train the model, reconstruct matrices, and compute reconstruction errors.

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device: {device}')


def set_seed(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)


def train_linear_ae(
    x_train_tensor: torch.Tensor,
    x_val_tensor: torch.Tensor,
    latent_dim: int,
    epochs: int = 80,
    batch_size: int = 64,
    lr: float = 1e-3,
    weight_decay: float = 0.0,
    seed: int = 42,
    scheduler_name: str = 'none',
    cosine_t_max: int = 80,
    cosine_eta_min: float = 1e-8,
    step_size: int = 10,
    step_gamma: float = 0.5,
    plateau_factor: float = 0.5,
    plateau_patience: int = 5,
    plateau_threshold: float = 1e-3,
    plateau_min_lr: float = 1e-8,
    resume_state_dict=None,
    initial_best_val=None,
):

    # 1) Seed for reproducibility
    set_seed(seed)

    # 2) Model, optimizer, criterion, scheduler
    model = LinearAutoencoder(input_dim=x_train_tensor.shape[1], latent_dim=latent_dim).to(device)
    if resume_state_dict is not None:
        model.load_state_dict(resume_state_dict)

    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    criterion = nn.MSELoss()

    scheduler_key = str(scheduler_name).strip().lower()
    valid_schedulers = {'none', 'cosine', 'step', 'plateau'}
    if scheduler_key not in valid_schedulers:
        raise ValueError(f"Invalid scheduler '{scheduler_name}'. Choose one of {sorted(valid_schedulers)}")

    scheduler = None
    if scheduler_key == 'cosine':
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
            optimizer,
            T_max=cosine_t_max,
            eta_min=cosine_eta_min,
        )
    elif scheduler_key == 'step':
        scheduler = torch.optim.lr_scheduler.StepLR(
            optimizer,
            step_size=step_size,
            gamma=step_gamma,
        )
    elif scheduler_key == 'plateau':
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
            optimizer,
            mode='min',
            factor=plateau_factor,
            patience=plateau_patience,
            threshold=plateau_threshold,
            min_lr=plateau_min_lr,
        )

    # 3) DataLoaders
    train_loader = DataLoader(TensorDataset(x_train_tensor), batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(TensorDataset(x_val_tensor), batch_size=batch_size, shuffle=False)

    history = {'train_loss': [], 'val_loss': [], 'lr': []}

    # 4) Initialization of best validation loss
    if resume_state_dict is not None:
        if initial_best_val is None:
            model.eval()
            val_loss_sum = 0.0
            with torch.no_grad():
                for (xb,) in val_loader:
                    xb = xb.to(device)
                    pred = model(xb)
                    loss = criterion(pred, xb)
                    val_loss_sum += loss.item() * xb.size(0)
            initial_best_val = val_loss_sum / len(val_loader.dataset)

        best_val = float(initial_best_val)
        best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
    else:
        best_val = float('inf')
        best_state = None

    # 5) Training loop
    for epoch in range(epochs):
        model.train()
        train_loss_sum = 0.0
        current_lr = float(optimizer.param_groups[0]['lr'])

        for (xb,) in train_loader:
            xb = xb.to(device)
            optimizer.zero_grad()
            pred = model(xb)
            loss = criterion(pred, xb)
            loss.backward()
            optimizer.step()
            train_loss_sum += loss.item() * xb.size(0)

        train_loss = train_loss_sum / len(train_loader.dataset)

        model.eval()
        val_loss_sum = 0.0
        with torch.no_grad():
            for (xb,) in val_loader:
                xb = xb.to(device)
                pred = model(xb)
                loss = criterion(pred, xb)
                val_loss_sum += loss.item() * xb.size(0)

        val_loss = val_loss_sum / len(val_loader.dataset)
        history['train_loss'].append(train_loss)
        history['val_loss'].append(val_loss)
        history['lr'].append(current_lr)

        if scheduler is not None:
            if scheduler_key == 'plateau':
                scheduler.step(val_loss)
            else:
                scheduler.step()

        if val_loss < best_val:
            best_val = val_loss
            best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}

        print(f'Epoch {epoch + 1:>3}/{epochs} | lr={current_lr:.2e} | train_loss={train_loss:.6f} | val_loss={val_loss:.6f}')

    # 6) Load best state and return
    if best_state is None:
        best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}

    model.load_state_dict(best_state)

    return model, history, best_val


def reconstruct_matrices(model: nn.Module, x_tensor: torch.Tensor, n_assets: int, batch_size: int = 4):
    model.eval()
    loader = DataLoader(TensorDataset(x_tensor), batch_size=batch_size, shuffle=False)
    outputs = []

    with torch.no_grad():
        for (xb,) in loader:
            xb = xb.to(device)
            pred = model(xb).cpu().numpy()
            outputs.append(pred)

    recon_flat = np.concatenate(outputs, axis=0)
    recon = recon_flat.reshape(-1, n_assets, n_assets).astype(np.float32)

    # Enforce correlation-matrix structure after reconstruction.
    #recon = 0.5 * (recon + np.transpose(recon, (0, 2, 1)))
    #diag_idx = np.arange(n_assets)
    #recon[:, diag_idx, diag_idx] = 1.0

    return recon


def reconstruction_errors(original: np.ndarray, reconstructed: np.ndarray):
    diff = original - reconstructed

    mse_per_matrix = np.mean(diff ** 2, axis=(1, 2))
    mae_per_matrix = np.mean(np.abs(diff), axis=(1, 2))
    fro_per_matrix = np.linalg.norm(diff, ord='fro', axis=(1, 2))

    summary = pd.DataFrame({
        'MSE': mse_per_matrix,
        'MAE': mae_per_matrix,
        'Frobenius': fro_per_matrix,
    })

    stats = summary.agg(['mean', 'std', 'min', 'median', 'max']).T
    return summary, stats
# Out:
# Device: cuda

# %% [markdown]
# ## Step 5: Train One Configuration and Reconstruct Matrices
# Train one linear AE configuration, reconstruct all matrices, and inspect training losses.

# %%
SEED = 42
RUN = 'linearAE_005'
RESUME_TRAINING = True
RESUME_MODEL_PATH = "best_models_tesi/linearAE/linearAE_004/linear_AE_best_linearAE_004.pt"  # Example: 'best_models_tesi/linearAE/<RUN>/linear_AE_best_<RUN>.pt'

if IS_COLAB:
    run_dir = Path('/content/drive/MyDrive/best_models_tesi/linearAE')
else:
    run_dir = project_root / 'models' / 'best_models_tesi' / 'linearAE'

run_output_dir = run_dir / RUN
run_output_dir.mkdir(parents=True, exist_ok=True)
print(f'Results directory: {run_output_dir}')
print(f'Resume training: {RESUME_TRAINING}')
# Out:
# Results directory: /content/drive/MyDrive/best_models_tesi/linearAE/linearAE_005
# Resume training: True

# %%
LATENT_DIM = 3
EPOCHS = 1000
BATCH_SIZE = 32
LR = 1e-5
WEIGHT_DECAY = 1e-6
# Scheduler selector: 'none', 'cosine', 'step', 'plateau'
SCHEDULER_NAME = 'cosine'

# 1) CosineAnnealingLR params
COSINE_T_MAX = EPOCHS
COSINE_ETA_MIN = 1e-8

# 2) StepLR params
STEP_SIZE = 10
STEP_GAMMA = 0.5

# 3) ReduceLROnPlateau params
PLATEAU_FACTOR = 0.5
PLATEAU_PATIENCE = 5
PLATEAU_THRESHOLD = 1e-3
PLATEAU_MIN_LR = 1e-8




resume_state_dict = None
resume_initial_val = None
resume_source_path = None
# Resume logic: load checkpoint, check compatibility, extract state dict and initial val loss if available
if RESUME_TRAINING:
    if RESUME_MODEL_PATH is None:
        raise ValueError('RESUME_TRAINING=True but RESUME_MODEL_PATH is None.')

    resume_source_path = Path(RESUME_MODEL_PATH)
    if not resume_source_path.is_absolute():
        if IS_COLAB:
            resume_source_path = Path('/content/drive/MyDrive') / resume_source_path
        else:
            resume_source_path = project_root / resume_source_path
    resume_source_path = resume_source_path.resolve()

    if not resume_source_path.exists():
        raise FileNotFoundError(f'Checkpoint not found: {resume_source_path}')

    checkpoint = torch.load(resume_source_path, map_location=device)
    state_dict = checkpoint['model_state_dict'] if isinstance(checkpoint, dict) and 'model_state_dict' in checkpoint else checkpoint

    probe_model = LinearAutoencoder(input_dim=x_train.shape[1], latent_dim=LATENT_DIM)
    current_shapes = {k: tuple(v.shape) for k, v in probe_model.state_dict().items()}
    loaded_shapes = {k: tuple(v.shape) for k, v in state_dict.items()}

    missing_keys = [k for k in current_shapes.keys() if k not in loaded_shapes]
    shape_mismatches = [
        (k, loaded_shapes[k], current_shapes[k])
        for k in current_shapes.keys()
        if k in loaded_shapes and loaded_shapes[k] != current_shapes[k]
    ]

    if missing_keys or shape_mismatches:
        hint = ''
        if 'encoder.weight' in loaded_shapes:
            ckpt_latent_dim = loaded_shapes['encoder.weight'][0]
            ckpt_input_dim = loaded_shapes['encoder.weight'][1]
            hint = f'Checkpoint expects input_dim={ckpt_input_dim}, latent_dim={ckpt_latent_dim}.'

        details = []
        if missing_keys:
            details.append(f'Missing keys (first 5): {missing_keys[:5]}')
        if shape_mismatches:
            k, loaded_shape, current_shape = shape_mismatches[0]
            details.append(f'Shape mismatch example: {k} loaded={loaded_shape}, current={current_shape}')

        raise RuntimeError(
            'Incompatible checkpoint for current LinearAutoencoder. ' + hint + (' | ' + ' ; '.join(details) if details else '')
        )

    resume_state_dict = state_dict
    if isinstance(checkpoint, dict) and 'best_val_loss' in checkpoint:
        resume_initial_val = float(checkpoint['best_val_loss'])

    if resume_initial_val is None:
        temp_model = LinearAutoencoder(input_dim=x_train.shape[1], latent_dim=LATENT_DIM).to(device)
        temp_model.load_state_dict(resume_state_dict)
        temp_model.eval()

        val_loader = DataLoader(TensorDataset(x_val), batch_size=BATCH_SIZE, shuffle=False)
        criterion = nn.MSELoss()
        val_loss_sum = 0.0
        with torch.no_grad():
            for (xb,) in val_loader:
                xb = xb.to(device)
                pred = temp_model(xb)
                loss = criterion(pred, xb)
                val_loss_sum += loss.item() * xb.size(0)
        resume_initial_val = val_loss_sum / len(val_loader.dataset)

    print(f'Loaded checkpoint: {resume_source_path}')
    print(f'Checkpoint validation MSE (baseline for resume): {resume_initial_val:.6f}')







# Train the model (or resume training if applicable)
model, history, best_val = train_linear_ae(
    x_train_tensor=x_train,
    x_val_tensor=x_val,
    latent_dim=LATENT_DIM,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    lr=LR,
    weight_decay=WEIGHT_DECAY,
    seed=SEED,
    scheduler_name=SCHEDULER_NAME,
    cosine_t_max=COSINE_T_MAX,
    cosine_eta_min=COSINE_ETA_MIN,
    step_size=STEP_SIZE,
    step_gamma=STEP_GAMMA,
    plateau_factor=PLATEAU_FACTOR,
    plateau_patience=PLATEAU_PATIENCE,
    plateau_threshold=PLATEAU_THRESHOLD,
    plateau_min_lr=PLATEAU_MIN_LR,
    resume_state_dict=resume_state_dict,
    initial_best_val=resume_initial_val,
 )




best_model_path = run_output_dir / f'linear_AE_best_{RUN}.pt'
torch.save(
    {
        'model_state_dict': model.state_dict(),
        'model_config': {
            'input_dim': int(x_train.shape[1]),
            'latent_dim': int(LATENT_DIM),
            'epochs': int(EPOCHS),
            'batch_size': int(BATCH_SIZE),
            'lr': float(LR),
            'weight_decay': float(WEIGHT_DECAY),
            'seed': int(SEED),
            'scheduler': {
                'key': str(SCHEDULER_NAME).strip().lower(),
            },
        },
        'best_val_loss': float(best_val),
    },
    best_model_path,
 )
print(f'Saved best model: {best_model_path}')
print(f'Best validation loss: {best_val:.6f}')



fig, ax = plt.subplots(figsize=(8, 4))
epochs_to_plot = list(range(5, EPOCHS))
ax.plot(epochs_to_plot, history['train_loss'][5:], label='Train Loss', linewidth=2)
ax.plot(epochs_to_plot, history['val_loss'][5:], label='Val Loss', linewidth=2)
ax.set_title('Training Curve (Linear AE)', fontsize=12, fontweight='bold')
ax.set_xlabel('Epoch')
ax.set_yscale('log')
ax.set_ylabel('MSE Loss (log scale)')
ax.grid(True, alpha=0.3)
ax.legend()
plt.tight_layout()

train_curve_path = run_output_dir / f'linear_AE_training_curve_{RUN}.png'
fig.savefig(train_curve_path, dpi=150, bbox_inches='tight')
plt.show()
print(f'Saved training curve: {train_curve_path}')
# Out:
# Loaded checkpoint: /content/drive/MyDrive/best_models_tesi/linearAE/linearAE_004/linear_AE_best_linearAE_004.pt
# Checkpoint validation MSE (baseline for resume): 0.008628
# Epoch   1/1000 | lr=1.00e-05 | train_loss=0.024639 | val_loss=0.028521
# Epoch   2/1000 | lr=1.00e-05 | train_loss=0.016044 | val_loss=0.010842
# Epoch   3/1000 | lr=1.00e-05 | train_loss=0.011186 | val_loss=0.008977
# Epoch   4/1000 | lr=1.00e-05 | train_loss=0.009038 | val_loss=0.009047
# Epoch   5/1000 | lr=1.00e-05 | train_loss=0.008688 | val_loss=0.008962
# Epoch   6/1000 | lr=1.00e-05 | train_loss=0.008472 | val_loss=0.008713
# Epoch   7/1000 | lr=1.00e-05 | train_loss=0.008390 | val_loss=0.008649
# Epoch   8/1000 | lr=1.00e-05 | train_loss=0.008361 | val_loss=0.008629
# Epoch   9/1000 | lr=1.00e-05 | train_loss=0.008350 | val_loss=0.008626
# Epoch  10/1000 | lr=1.00e-05 | train_loss=0.008349 | val_loss=0.008624
# Epoch  11/1000 | lr=1.00e-05 | train_loss=0.008343 | val_loss=0.008623
# Epoch  12/1000 | lr=1.00e-05 | train_loss=0.008341 | val_loss=0.008623
# Epoch  13/1000 | lr=1.00e-05 | train_loss=0.008342 | val_loss=0.008622
# Epoch  14/1000 | lr=1.00e-05 | train_loss=0.008340 | val_loss=0.008618
# Epoch  15/1000 | lr=1.00e-05 | train_loss=0.008338 | val_loss=0.008617
# Epoch  16/1000 | lr=9.99e-06 | train_loss=0.008337 | val_loss=0.008615
# Epoch  17/1000 | lr=9.99e-06 | train_loss=0.008335 | val_loss=0.008614
# Epoch  18/1000 | lr=9.99e-06 | train_loss=0.008334 | val_loss=0.008613
# Epoch  19/1000 | lr=9.99e-06 | train_loss=0.008334 | val_loss=0.008613
# Epoch  20/1000 | lr=9.99e-06 | train_loss=0.008333 | val_loss=0.008611
# Epoch  21/1000 | lr=9.99e-06 | train_loss=0.008332 | val_loss=0.008611
# Epoch  22/1000 | lr=9.99e-06 | train_loss=0.008332 | val_loss=0.008610
# Epoch  23/1000 | lr=9.99e-06 | train_loss=0.008331 | val_loss=0.008609
# Epoch  24/1000 | lr=9.99e-06 | train_loss=0.008330 | val_loss=0.008609
# Epoch  25/1000 | lr=9.99e-06 | train_loss=0.008329 | val_loss=0.008607
# Epoch  26/1000 | lr=9.98e-06 | train_loss=0.008328 | val_loss=0.008607
# Epoch  27/1000 | lr=9.98e-06 | train_loss=0.008327 | val_loss=0.008606
# Epoch  28/1000 | lr=9.98e-06 | train_loss=0.008327 | val_loss=0.008606
# Epoch  29/1000 | lr=9.98e-06 | train_loss=0.008326 | val_loss=0.008606
# Epoch  30/1000 | lr=9.98e-06 | train_loss=0.008327 | val_loss=0.008604
# Epoch  31/1000 | lr=9.98e-06 | train_loss=0.008325 | val_loss=0.008602
# Epoch  32/1000 | lr=9.98e-06 | train_loss=0.008324 | val_loss=0.008601
# Epoch  33/1000 | lr=9.97e-06 | train_loss=0.008323 | val_loss=0.008600
# Epoch  34/1000 | lr=9.97e-06 | train_loss=0.008322 | val_loss=0.008598
# Epoch  35/1000 | lr=9.97e-06 | train_loss=0.008321 | val_loss=0.008597
# Epoch  36/1000 | lr=9.97e-06 | train_loss=0.008320 | val_loss=0.008597
# Epoch  37/1000 | lr=9.97e-06 | train_loss=0.008319 | val_loss=0.008596
# Epoch  38/1000 | lr=9.97e-06 | train_loss=0.008318 | val_loss=0.008596
# Epoch  39/1000 | lr=9.96e-06 | train_loss=0.008318 | val_loss=0.008594
# Epoch  40/1000 | lr=9.96e-06 | train_loss=0.008317 | val_loss=0.008594
# Epoch  41/1000 | lr=9.96e-06 | train_loss=0.008316 | val_loss=0.008593
# Epoch  42/1000 | lr=9.96e-06 | train_loss=0.008315 | val_loss=0.008593
# Epoch  43/1000 | lr=9.96e-06 | train_loss=0.008314 | val_loss=0.008591
# Epoch  44/1000 | lr=9.95e-06 | train_loss=0.008313 | val_loss=0.008590
# Epoch  45/1000 | lr=9.95e-06 | train_loss=0.008312 | val_loss=0.008589
# Epoch  46/1000 | lr=9.95e-06 | train_loss=0.008311 | val_loss=0.008587
# Epoch  47/1000 | lr=9.95e-06 | train_loss=0.008310 | val_loss=0.008587
# Epoch  48/1000 | lr=9.95e-06 | train_loss=0.008309 | val_loss=0.008586
# Epoch  49/1000 | lr=9.94e-06 | train_loss=0.008308 | val_loss=0.008587
# Epoch  50/1000 | lr=9.94e-06 | train_loss=0.008307 | val_loss=0.008585
# Epoch  51/1000 | lr=9.94e-06 | train_loss=0.008306 | val_loss=0.008584
# Epoch  52/1000 | lr=9.94e-06 | train_loss=0.008304 | val_loss=0.008583
# Epoch  53/1000 | lr=9.93e-06 | train_loss=0.008304 | val_loss=0.008582
# Epoch  54/1000 | lr=9.93e-06 | train_loss=0.008303 | val_loss=0.008582
# Epoch  55/1000 | lr=9.93e-06 | train_loss=0.008302 | val_loss=0.008581
# Epoch  56/1000 | lr=9.93e-06 | train_loss=0.008301 | val_loss=0.008579
# Epoch  57/1000 | lr=9.92e-06 | train_loss=0.008300 | val_loss=0.008578
# Epoch  58/1000 | lr=9.92e-06 | train_loss=0.008299 | val_loss=0.008577
# Epoch  59/1000 | lr=9.92e-06 | train_loss=0.008298 | val_loss=0.008577
# Epoch  60/1000 | lr=9.91e-06 | train_loss=0.008296 | val_loss=0.008576
# Epoch  61/1000 | lr=9.91e-06 | train_loss=0.008295 | val_loss=0.008576
# Epoch  62/1000 | lr=9.91e-06 | train_loss=0.008294 | val_loss=0.008576
# Epoch  63/1000 | lr=9.91e-06 | train_loss=0.008294 | val_loss=0.008575
# Epoch  64/1000 | lr=9.90e-06 | train_loss=0.008293 | val_loss=0.008573
# Epoch  65/1000 | lr=9.90e-06 | train_loss=0.008292 | val_loss=0.008572
# Epoch  66/1000 | lr=9.90e-06 | train_loss=0.008291 | val_loss=0.008572
# Epoch  67/1000 | lr=9.89e-06 | train_loss=0.008291 | val_loss=0.008570
# Epoch  68/1000 | lr=9.89e-06 | train_loss=0.008290 | val_loss=0.008570
# Epoch  69/1000 | lr=9.89e-06 | train_loss=0.008289 | val_loss=0.008569
# Epoch  70/1000 | lr=9.88e-06 | train_loss=0.008288 | val_loss=0.008567
# Epoch  71/1000 | lr=9.88e-06 | train_loss=0.008287 | val_loss=0.008566
# Epoch  72/1000 | lr=9.88e-06 | train_loss=0.008287 | val_loss=0.008568
# Epoch  73/1000 | lr=9.87e-06 | train_loss=0.008287 | val_loss=0.008563
# Epoch  74/1000 | lr=9.87e-06 | train_loss=0.008285 | val_loss=0.008563
# Epoch  75/1000 | lr=9.87e-06 | train_loss=0.008283 | val_loss=0.008563
# Epoch  76/1000 | lr=9.86e-06 | train_loss=0.008283 | val_loss=0.008562
# Epoch  77/1000 | lr=9.86e-06 | train_loss=0.008282 | val_loss=0.008562
# Epoch  78/1000 | lr=9.85e-06 | train_loss=0.008281 | val_loss=0.008560
# Epoch  79/1000 | lr=9.85e-06 | train_loss=0.008280 | val_loss=0.008559
# Epoch  80/1000 | lr=9.85e-06 | train_loss=0.008278 | val_loss=0.008560
# Epoch  81/1000 | lr=9.84e-06 | train_loss=0.008278 | val_loss=0.008561
# Epoch  82/1000 | lr=9.84e-06 | train_loss=0.008278 | val_loss=0.008556
# Epoch  83/1000 | lr=9.84e-06 | train_loss=0.008276 | val_loss=0.008555
# Epoch  84/1000 | lr=9.83e-06 | train_loss=0.008275 | val_loss=0.008553
# Epoch  85/1000 | lr=9.83e-06 | train_loss=0.008273 | val_loss=0.008552
# Epoch  86/1000 | lr=9.82e-06 | train_loss=0.008272 | val_loss=0.008554
# Epoch  87/1000 | lr=9.82e-06 | train_loss=0.008273 | val_loss=0.008550
# Epoch  88/1000 | lr=9.81e-06 | train_loss=0.008271 | val_loss=0.008549
# Epoch  89/1000 | lr=9.81e-06 | train_loss=0.008270 | val_loss=0.008548
# Epoch  90/1000 | lr=9.81e-06 | train_loss=0.008269 | val_loss=0.008548
# Epoch  91/1000 | lr=9.80e-06 | train_loss=0.008269 | val_loss=0.008546
# Epoch  92/1000 | lr=9.80e-06 | train_loss=0.008268 | val_loss=0.008547
# Epoch  93/1000 | lr=9.79e-06 | train_loss=0.008267 | val_loss=0.008546
# Epoch  94/1000 | lr=9.79e-06 | train_loss=0.008266 | val_loss=0.008544
# Epoch  95/1000 | lr=9.78e-06 | train_loss=0.008265 | val_loss=0.008543
# Epoch  96/1000 | lr=9.78e-06 | train_loss=0.008264 | val_loss=0.008542
# Epoch  97/1000 | lr=9.77e-06 | train_loss=0.008263 | val_loss=0.008541
# Epoch  98/1000 | lr=9.77e-06 | train_loss=0.008262 | val_loss=0.008541
# Epoch  99/1000 | lr=9.77e-06 | train_loss=0.008262 | val_loss=0.008539
# Epoch 100/1000 | lr=9.76e-06 | train_loss=0.008261 | val_loss=0.008538
# Epoch 101/1000 | lr=9.76e-06 | train_loss=0.008260 | val_loss=0.008538
# Epoch 102/1000 | lr=9.75e-06 | train_loss=0.008260 | val_loss=0.008537
# Epoch 103/1000 | lr=9.75e-06 | train_loss=0.008260 | val_loss=0.008537
# Epoch 104/1000 | lr=9.74e-06 | train_loss=0.008259 | val_loss=0.008538
# Epoch 105/1000 | lr=9.74e-06 | train_loss=0.008258 | val_loss=0.008535
# Epoch 106/1000 | lr=9.73e-06 | train_loss=0.008256 | val_loss=0.008537
# Epoch 107/1000 | lr=9.73e-06 | train_loss=0.008256 | val_loss=0.008534
# Epoch 108/1000 | lr=9.72e-06 | train_loss=0.008255 | val_loss=0.008533
# Epoch 109/1000 | lr=9.72e-06 | train_loss=0.008253 | val_loss=0.008530
# Epoch 110/1000 | lr=9.71e-06 | train_loss=0.008252 | val_loss=0.008533
# Epoch 111/1000 | lr=9.70e-06 | train_loss=0.008252 | val_loss=0.008533
# Epoch 112/1000 | lr=9.70e-06 | train_loss=0.008252 | val_loss=0.008531
# Epoch 113/1000 | lr=9.69e-06 | train_loss=0.008251 | val_loss=0.008529
# Epoch 114/1000 | lr=9.69e-06 | train_loss=0.008249 | val_loss=0.008527
# Epoch 115/1000 | lr=9.68e-06 | train_loss=0.008248 | val_loss=0.008526
# Epoch 116/1000 | lr=9.68e-06 | train_loss=0.008247 | val_loss=0.008526
# Epoch 117/1000 | lr=9.67e-06 | train_loss=0.008247 | val_loss=0.008525
# Epoch 118/1000 | lr=9.67e-06 | train_loss=0.008246 | val_loss=0.008522
# Epoch 119/1000 | lr=9.66e-06 | train_loss=0.008244 | val_loss=0.008520
# Epoch 120/1000 | lr=9.65e-06 | train_loss=0.008243 | val_loss=0.008519
# Epoch 121/1000 | lr=9.65e-06 | train_loss=0.008242 | val_loss=0.008522
# Epoch 122/1000 | lr=9.64e-06 | train_loss=0.008243 | val_loss=0.008519
# Epoch 123/1000 | lr=9.64e-06 | train_loss=0.008242 | val_loss=0.008517
# Epoch 124/1000 | lr=9.63e-06 | train_loss=0.008240 | val_loss=0.008517
# Epoch 125/1000 | lr=9.63e-06 | train_loss=0.008240 | val_loss=0.008519
# Epoch 126/1000 | lr=9.62e-06 | train_loss=0.008240 | val_loss=0.008519
# Epoch 127/1000 | lr=9.61e-06 | train_loss=0.008240 | val_loss=0.008517
# Epoch 128/1000 | lr=9.61e-06 | train_loss=0.008238 | val_loss=0.008516
# Epoch 129/1000 | lr=9.60e-06 | train_loss=0.008237 | val_loss=0.008517
# Epoch 130/1000 | lr=9.60e-06 | train_loss=0.008239 | val_loss=0.008533
# Epoch 131/1000 | lr=9.59e-06 | train_loss=0.008244 | val_loss=0.008526
# Epoch 132/1000 | lr=9.58e-06 | train_loss=0.008241 | val_loss=0.008537
# Epoch 133/1000 | lr=9.58e-06 | train_loss=0.008249 | val_loss=0.008614
# Epoch 134/1000 | lr=9.57e-06 | train_loss=0.008281 | val_loss=0.008509
# Epoch 135/1000 | lr=9.56e-06 | train_loss=0.008248 | val_loss=0.008537
# Epoch 136/1000 | lr=9.56e-06 | train_loss=0.008251 | val_loss=0.008535
# Epoch 137/1000 | lr=9.55e-06 | train_loss=0.008241 | val_loss=0.008521
# Epoch 138/1000 | lr=9.54e-06 | train_loss=0.008237 | val_loss=0.008512
# Epoch 139/1000 | lr=9.54e-06 | train_loss=0.008231 | val_loss=0.008505
# Epoch 140/1000 | lr=9.53e-06 | train_loss=0.008230 | val_loss=0.008523
# Epoch 141/1000 | lr=9.52e-06 | train_loss=0.008236 | val_loss=0.008515
# Epoch 142/1000 | lr=9.52e-06 | train_loss=0.008242 | val_loss=0.008574
# Epoch 143/1000 | lr=9.51e-06 | train_loss=0.008283 | val_loss=0.008712
# Epoch 144/1000 | lr=9.50e-06 | train_loss=0.008315 | val_loss=0.008725
# Epoch 145/1000 | lr=9.50e-06 | train_loss=0.008314 | val_loss=0.008773
# Epoch 146/1000 | lr=9.49e-06 | train_loss=0.008330 | val_loss=0.008778
# Epoch 147/1000 | lr=9.48e-06 | train_loss=0.008330 | val_loss=0.008569
# Epoch 148/1000 | lr=9.48e-06 | train_loss=0.008267 | val_loss=0.008713
# Epoch 149/1000 | lr=9.47e-06 | train_loss=0.008330 | val_loss=0.008516
# Epoch 150/1000 | lr=9.46e-06 | train_loss=0.008235 | val_loss=0.008533
# Epoch 151/1000 | lr=9.46e-06 | train_loss=0.008225 | val_loss=0.008523
# Epoch 152/1000 | lr=9.45e-06 | train_loss=0.008229 | val_loss=0.008550
# Epoch 153/1000 | lr=9.44e-06 | train_loss=0.008234 | val_loss=0.008513
# Epoch 154/1000 | lr=9.43e-06 | train_loss=0.008231 | val_loss=0.008505
# Epoch 155/1000 | lr=9.43e-06 | train_loss=0.008240 | val_loss=0.008522
# Epoch 156/1000 | lr=9.42e-06 | train_loss=0.008225 | val_loss=0.008522
# Epoch 157/1000 | lr=9.41e-06 | train_loss=0.008223 | val_loss=0.008489
# Epoch 158/1000 | lr=9.40e-06 | train_loss=0.008212 | val_loss=0.008489
# Epoch 159/1000 | lr=9.40e-06 | train_loss=0.008212 | val_loss=0.008488
# Epoch 160/1000 | lr=9.39e-06 | train_loss=0.008211 | val_loss=0.008499
# Epoch 161/1000 | lr=9.38e-06 | train_loss=0.008220 | val_loss=0.008508
# Epoch 162/1000 | lr=9.37e-06 | train_loss=0.008219 | val_loss=0.008543
# Epoch 163/1000 | lr=9.37e-06 | train_loss=0.008253 | val_loss=0.008565
# Epoch 164/1000 | lr=9.36e-06 | train_loss=0.008250 | val_loss=0.008610
# Epoch 165/1000 | lr=9.35e-06 | train_loss=0.008321 | val_loss=0.008699
# Epoch 166/1000 | lr=9.34e-06 | train_loss=0.008383 | val_loss=0.009064
# Epoch 167/1000 | lr=9.34e-06 | train_loss=0.008397 | val_loss=0.008773
# Epoch 168/1000 | lr=9.33e-06 | train_loss=0.008347 | val_loss=0.008652
# Epoch 169/1000 | lr=9.32e-06 | train_loss=0.008282 | val_loss=0.008580
# Epoch 170/1000 | lr=9.31e-06 | train_loss=0.008304 | val_loss=0.008697
# Epoch 171/1000 | lr=9.30e-06 | train_loss=0.008317 | val_loss=0.008549
# Epoch 172/1000 | lr=9.30e-06 | train_loss=0.008228 | val_loss=0.008517
# Epoch 173/1000 | lr=9.29e-06 | train_loss=0.008247 | val_loss=0.008568
# Epoch 174/1000 | lr=9.28e-06 | train_loss=0.008238 | val_loss=0.008667
# Epoch 175/1000 | lr=9.27e-06 | train_loss=0.008324 | val_loss=0.008708
# Epoch 176/1000 | lr=9.26e-06 | train_loss=0.008297 | val_loss=0.008575
# Epoch 177/1000 | lr=9.26e-06 | train_loss=0.008244 | val_loss=0.008486
# Epoch 178/1000 | lr=9.25e-06 | train_loss=0.008221 | val_loss=0.008490
# Epoch 179/1000 | lr=9.24e-06 | train_loss=0.008231 | val_loss=0.008522
# Epoch 180/1000 | lr=9.23e-06 | train_loss=0.008222 | val_loss=0.008498
# Epoch 181/1000 | lr=9.22e-06 | train_loss=0.008209 | val_loss=0.008534
# Epoch 182/1000 | lr=9.21e-06 | train_loss=0.008217 | val_loss=0.008541
# Epoch 183/1000 | lr=9.21e-06 | train_loss=0.008230 | val_loss=0.008467
# Epoch 184/1000 | lr=9.20e-06 | train_loss=0.008205 | val_loss=0.008468
# Epoch 185/1000 | lr=9.19e-06 | train_loss=0.008208 | val_loss=0.008490
# Epoch 186/1000 | lr=9.18e-06 | train_loss=0.008203 | val_loss=0.008465
# Epoch 187/1000 | lr=9.17e-06 | train_loss=0.008197 | val_loss=0.008498
# Epoch 188/1000 | lr=9.16e-06 | train_loss=0.008217 | val_loss=0.008502
# Epoch 189/1000 | lr=9.15e-06 | train_loss=0.008217 | val_loss=0.008515
# Epoch 190/1000 | lr=9.15e-06 | train_loss=0.008244 | val_loss=0.008565
# Epoch 191/1000 | lr=9.14e-06 | train_loss=0.008272 | val_loss=0.008525
# Epoch 192/1000 | lr=9.13e-06 | train_loss=0.008221 | val_loss=0.008783
# Epoch 193/1000 | lr=9.12e-06 | train_loss=0.008443 | val_loss=0.008764
# Epoch 194/1000 | lr=9.11e-06 | train_loss=0.008327 | val_loss=0.008794
# Epoch 195/1000 | lr=9.10e-06 | train_loss=0.008332 | val_loss=0.008819
# Epoch 196/1000 | lr=9.09e-06 | train_loss=0.008288 | val_loss=0.008462
# Epoch 197/1000 | lr=9.08e-06 | train_loss=0.008242 | val_loss=0.008504
# Epoch 198/1000 | lr=9.07e-06 | train_loss=0.008237 | val_loss=0.008512
# Epoch 199/1000 | lr=9.06e-06 | train_loss=0.008197 | val_loss=0.008546
# Epoch 200/1000 | lr=9.06e-06 | train_loss=0.008235 | val_loss=0.008510
# Epoch 201/1000 | lr=9.05e-06 | train_loss=0.008289 | val_loss=0.008742
# Epoch 202/1000 | lr=9.04e-06 | train_loss=0.008362 | val_loss=0.008912
# Epoch 203/1000 | lr=9.03e-06 | train_loss=0.008461 | val_loss=0.008761
# Epoch 204/1000 | lr=9.02e-06 | train_loss=0.008375 | val_loss=0.008604
# Epoch 205/1000 | lr=9.01e-06 | train_loss=0.008233 | val_loss=0.009042
# Epoch 206/1000 | lr=9.00e-06 | train_loss=0.008593 | val_loss=0.008922
# Epoch 207/1000 | lr=8.99e-06 | train_loss=0.008428 | val_loss=0.008504
# Epoch 208/1000 | lr=8.98e-06 | train_loss=0.008238 | val_loss=0.008824
# Epoch 209/1000 | lr=8.97e-06 | train_loss=0.008341 | val_loss=0.008914
# Epoch 210/1000 | lr=8.96e-06 | train_loss=0.008371 | val_loss=0.008458
# Epoch 211/1000 | lr=8.95e-06 | train_loss=0.008265 | val_loss=0.008687
# Epoch 212/1000 | lr=8.94e-06 | train_loss=0.008265 | val_loss=0.008450
# Epoch 213/1000 | lr=8.93e-06 | train_loss=0.008204 | val_loss=0.008496
# Epoch 214/1000 | lr=8.92e-06 | train_loss=0.008187 | val_loss=0.008450
# Epoch 215/1000 | lr=8.91e-06 | train_loss=0.008175 | val_loss=0.008452
# Epoch 216/1000 | lr=8.90e-06 | train_loss=0.008172 | val_loss=0.008475
# Epoch 217/1000 | lr=8.89e-06 | train_loss=0.008181 | val_loss=0.008482
# Epoch 218/1000 | lr=8.88e-06 | train_loss=0.008181 | val_loss=0.008449
# Epoch 219/1000 | lr=8.87e-06 | train_loss=0.008171 | val_loss=0.008487
# Epoch 220/1000 | lr=8.86e-06 | train_loss=0.008177 | val_loss=0.008466
# Epoch 221/1000 | lr=8.85e-06 | train_loss=0.008176 | val_loss=0.008448
# Epoch 222/1000 | lr=8.84e-06 | train_loss=0.008168 | val_loss=0.008484
# Epoch 223/1000 | lr=8.83e-06 | train_loss=0.008180 | val_loss=0.008476
# Epoch 224/1000 | lr=8.82e-06 | train_loss=0.008171 | val_loss=0.008448
# Epoch 225/1000 | lr=8.81e-06 | train_loss=0.008172 | val_loss=0.008521
# Epoch 226/1000 | lr=8.80e-06 | train_loss=0.008200 | val_loss=0.008439
# Epoch 227/1000 | lr=8.79e-06 | train_loss=0.008163 | val_loss=0.008467
# Epoch 228/1000 | lr=8.78e-06 | train_loss=0.008170 | val_loss=0.008429
# Epoch 229/1000 | lr=8.77e-06 | train_loss=0.008157 | val_loss=0.008449
# Epoch 230/1000 | lr=8.76e-06 | train_loss=0.008163 | val_loss=0.008453
# Epoch 231/1000 | lr=8.75e-06 | train_loss=0.008168 | val_loss=0.008434
# Epoch 232/1000 | lr=8.74e-06 | train_loss=0.008162 | val_loss=0.008443
# Epoch 233/1000 | lr=8.73e-06 | train_loss=0.008158 | val_loss=0.008493
# Epoch 234/1000 | lr=8.72e-06 | train_loss=0.008173 | val_loss=0.008426
# Epoch 235/1000 | lr=8.71e-06 | train_loss=0.008156 | val_loss=0.008462
# Epoch 236/1000 | lr=8.70e-06 | train_loss=0.008167 | val_loss=0.008510
# Epoch 237/1000 | lr=8.69e-06 | train_loss=0.008180 | val_loss=0.008425
# Epoch 238/1000 | lr=8.68e-06 | train_loss=0.008157 | val_loss=0.008423
# Epoch 239/1000 | lr=8.67e-06 | train_loss=0.008150 | val_loss=0.008424
# Epoch 240/1000 | lr=8.66e-06 | train_loss=0.008150 | val_loss=0.008419
# Epoch 241/1000 | lr=8.65e-06 | train_loss=0.008145 | val_loss=0.008419
# Epoch 242/1000 | lr=8.64e-06 | train_loss=0.008146 | val_loss=0.008425
# Epoch 243/1000 | lr=8.62e-06 | train_loss=0.008147 | val_loss=0.008426
# Epoch 244/1000 | lr=8.61e-06 | train_loss=0.008147 | val_loss=0.008415
# Epoch 245/1000 | lr=8.60e-06 | train_loss=0.008144 | val_loss=0.008416
# Epoch 246/1000 | lr=8.59e-06 | train_loss=0.008144 | val_loss=0.008413
# Epoch 247/1000 | lr=8.58e-06 | train_loss=0.008143 | val_loss=0.008431
# Epoch 248/1000 | lr=8.57e-06 | train_loss=0.008147 | val_loss=0.008427
# Epoch 249/1000 | lr=8.56e-06 | train_loss=0.008147 | val_loss=0.008419
# Epoch 250/1000 | lr=8.55e-06 | train_loss=0.008144 | val_loss=0.008432
# Epoch 251/1000 | lr=8.54e-06 | train_loss=0.008146 | val_loss=0.008411
# Epoch 252/1000 | lr=8.53e-06 | train_loss=0.008139 | val_loss=0.008409
# Epoch 253/1000 | lr=8.51e-06 | train_loss=0.008139 | val_loss=0.008405
# Epoch 254/1000 | lr=8.50e-06 | train_loss=0.008137 | val_loss=0.008424
# Epoch 255/1000 | lr=8.49e-06 | train_loss=0.008148 | val_loss=0.008473
# Epoch 256/1000 | lr=8.48e-06 | train_loss=0.008166 | val_loss=0.008498
# Epoch 257/1000 | lr=8.47e-06 | train_loss=0.008312 | val_loss=0.008423
# Epoch 258/1000 | lr=8.46e-06 | train_loss=0.008297 | val_loss=0.008450
# Epoch 259/1000 | lr=8.45e-06 | train_loss=0.008391 | val_loss=0.008929
# Epoch 260/1000 | lr=8.44e-06 | train_loss=0.008735 | val_loss=0.008880
# Epoch 261/1000 | lr=8.42e-06 | train_loss=0.008412 | val_loss=0.008598
# Epoch 262/1000 | lr=8.41e-06 | train_loss=0.008255 | val_loss=0.008406
# Epoch 263/1000 | lr=8.40e-06 | train_loss=0.008230 | val_loss=0.008444
# Epoch 264/1000 | lr=8.39e-06 | train_loss=0.008149 | val_loss=0.008423
# Epoch 265/1000 | lr=8.38e-06 | train_loss=0.008138 | val_loss=0.008418
# Epoch 266/1000 | lr=8.37e-06 | train_loss=0.008139 | val_loss=0.008399
# Epoch 267/1000 | lr=8.36e-06 | train_loss=0.008130 | val_loss=0.008425
# Epoch 268/1000 | lr=8.34e-06 | train_loss=0.008143 | val_loss=0.008397
# Epoch 269/1000 | lr=8.33e-06 | train_loss=0.008135 | val_loss=0.008406
# Epoch 270/1000 | lr=8.32e-06 | train_loss=0.008131 | val_loss=0.008401
# Epoch 271/1000 | lr=8.31e-06 | train_loss=0.008130 | val_loss=0.008395
# Epoch 272/1000 | lr=8.30e-06 | train_loss=0.008126 | val_loss=0.008401
# Epoch 273/1000 | lr=8.28e-06 | train_loss=0.008130 | val_loss=0.008393
# Epoch 274/1000 | lr=8.27e-06 | train_loss=0.008123 | val_loss=0.008398
# Epoch 275/1000 | lr=8.26e-06 | train_loss=0.008124 | val_loss=0.008403
# Epoch 276/1000 | lr=8.25e-06 | train_loss=0.008127 | val_loss=0.008392
# Epoch 277/1000 | lr=8.24e-06 | train_loss=0.008122 | val_loss=0.008388
# Epoch 278/1000 | lr=8.23e-06 | train_loss=0.008120 | val_loss=0.008393
# Epoch 279/1000 | lr=8.21e-06 | train_loss=0.008120 | val_loss=0.008390
# Epoch 280/1000 | lr=8.20e-06 | train_loss=0.008120 | val_loss=0.008401
# Epoch 281/1000 | lr=8.19e-06 | train_loss=0.008123 | val_loss=0.008388
# Epoch 282/1000 | lr=8.18e-06 | train_loss=0.008119 | val_loss=0.008386
# Epoch 283/1000 | lr=8.16e-06 | train_loss=0.008117 | val_loss=0.008386
# Epoch 284/1000 | lr=8.15e-06 | train_loss=0.008116 | val_loss=0.008385
# Epoch 285/1000 | lr=8.14e-06 | train_loss=0.008115 | val_loss=0.008387
# Epoch 286/1000 | lr=8.13e-06 | train_loss=0.008115 | val_loss=0.008385
# Epoch 287/1000 | lr=8.12e-06 | train_loss=0.008114 | val_loss=0.008383
# Epoch 288/1000 | lr=8.10e-06 | train_loss=0.008113 | val_loss=0.008385
# Epoch 289/1000 | lr=8.09e-06 | train_loss=0.008113 | val_loss=0.008382
# Epoch 290/1000 | lr=8.08e-06 | train_loss=0.008111 | val_loss=0.008389
# Epoch 291/1000 | lr=8.07e-06 | train_loss=0.008114 | val_loss=0.008388
# Epoch 292/1000 | lr=8.05e-06 | train_loss=0.008114 | val_loss=0.008405
# Epoch 293/1000 | lr=8.04e-06 | train_loss=0.008119 | val_loss=0.008398
# Epoch 294/1000 | lr=8.03e-06 | train_loss=0.008134 | val_loss=0.008405
# Epoch 295/1000 | lr=8.02e-06 | train_loss=0.008122 | val_loss=0.008383
# Epoch 296/1000 | lr=8.00e-06 | train_loss=0.008121 | val_loss=0.008386
# Epoch 297/1000 | lr=7.99e-06 | train_loss=0.008120 | val_loss=0.008400
# Epoch 298/1000 | lr=7.98e-06 | train_loss=0.008120 | val_loss=0.008384
# Epoch 299/1000 | lr=7.97e-06 | train_loss=0.008111 | val_loss=0.008379
# Epoch 300/1000 | lr=7.95e-06 | train_loss=0.008110 | val_loss=0.008388
# Epoch 301/1000 | lr=7.94e-06 | train_loss=0.008108 | val_loss=0.008382
# Epoch 302/1000 | lr=7.93e-06 | train_loss=0.008106 | val_loss=0.008387
# Epoch 303/1000 | lr=7.92e-06 | train_loss=0.008109 | val_loss=0.008378
# Epoch 304/1000 | lr=7.90e-06 | train_loss=0.008110 | val_loss=0.008375
# Epoch 305/1000 | lr=7.89e-06 | train_loss=0.008105 | val_loss=0.008385
# Epoch 306/1000 | lr=7.88e-06 | train_loss=0.008107 | val_loss=0.008429
# Epoch 307/1000 | lr=7.86e-06 | train_loss=0.008130 | val_loss=0.008559
# Epoch 308/1000 | lr=7.85e-06 | train_loss=0.008174 | val_loss=0.008619
# Epoch 309/1000 | lr=7.84e-06 | train_loss=0.008186 | val_loss=0.008404
# Epoch 310/1000 | lr=7.83e-06 | train_loss=0.008110 | val_loss=0.008448
# Epoch 311/1000 | lr=7.81e-06 | train_loss=0.008133 | val_loss=0.008494
# Epoch 312/1000 | lr=7.80e-06 | train_loss=0.008160 | val_loss=0.008450
# Epoch 313/1000 | lr=7.79e-06 | train_loss=0.008180 | val_loss=0.008949
# Epoch 314/1000 | lr=7.77e-06 | train_loss=0.008718 | val_loss=0.008374
# Epoch 315/1000 | lr=7.76e-06 | train_loss=0.008165 | val_loss=0.008536
# Epoch 316/1000 | lr=7.75e-06 | train_loss=0.008172 | val_loss=0.008382
# Epoch 317/1000 | lr=7.73e-06 | train_loss=0.008103 | val_loss=0.009266
# Epoch 318/1000 | lr=7.72e-06 | train_loss=0.008464 | val_loss=0.008577
# Epoch 319/1000 | lr=7.71e-06 | train_loss=0.008203 | val_loss=0.008566
# Epoch 320/1000 | lr=7.69e-06 | train_loss=0.008174 | val_loss=0.008367
# Epoch 321/1000 | lr=7.68e-06 | train_loss=0.008110 | val_loss=0.008367
# Epoch 322/1000 | lr=7.67e-06 | train_loss=0.008105 | val_loss=0.008382
# Epoch 323/1000 | lr=7.65e-06 | train_loss=0.008103 | val_loss=0.008380
# Epoch 324/1000 | lr=7.64e-06 | train_loss=0.008101 | val_loss=0.008399
# Epoch 325/1000 | lr=7.63e-06 | train_loss=0.008125 | val_loss=0.008373
# Epoch 326/1000 | lr=7.61e-06 | train_loss=0.008090 | val_loss=0.008357
# Epoch 327/1000 | lr=7.60e-06 | train_loss=0.008086 | val_loss=0.008355
# Epoch 328/1000 | lr=7.59e-06 | train_loss=0.008085 | val_loss=0.008354
# Epoch 329/1000 | lr=7.57e-06 | train_loss=0.008085 | val_loss=0.008354
# Epoch 330/1000 | lr=7.56e-06 | train_loss=0.008084 | val_loss=0.008353
# Epoch 331/1000 | lr=7.55e-06 | train_loss=0.008083 | val_loss=0.008356
# Epoch 332/1000 | lr=7.53e-06 | train_loss=0.008084 | val_loss=0.008351
# Epoch 333/1000 | lr=7.52e-06 | train_loss=0.008084 | val_loss=0.008350
# Epoch 334/1000 | lr=7.51e-06 | train_loss=0.008082 | val_loss=0.008355
# Epoch 335/1000 | lr=7.49e-06 | train_loss=0.008084 | val_loss=0.008352
# Epoch 336/1000 | lr=7.48e-06 | train_loss=0.008083 | val_loss=0.008350
# Epoch 337/1000 | lr=7.47e-06 | train_loss=0.008081 | val_loss=0.008355
# Epoch 338/1000 | lr=7.45e-06 | train_loss=0.008091 | val_loss=0.008367
# Epoch 339/1000 | lr=7.44e-06 | train_loss=0.008093 | val_loss=0.008359
# Epoch 340/1000 | lr=7.43e-06 | train_loss=0.008099 | val_loss=0.008345
# Epoch 341/1000 | lr=7.41e-06 | train_loss=0.008085 | val_loss=0.008453
# Epoch 342/1000 | lr=7.40e-06 | train_loss=0.008152 | val_loss=0.008352
# Epoch 343/1000 | lr=7.38e-06 | train_loss=0.008082 | val_loss=0.008361
# Epoch 344/1000 | lr=7.37e-06 | train_loss=0.008083 | val_loss=0.008366
# Epoch 345/1000 | lr=7.36e-06 | train_loss=0.008094 | val_loss=0.008347
# Epoch 346/1000 | lr=7.34e-06 | train_loss=0.008092 | val_loss=0.008369
# Epoch 347/1000 | lr=7.33e-06 | train_loss=0.008119 | val_loss=0.008363
# Epoch 348/1000 | lr=7.31e-06 | train_loss=0.008099 | val_loss=0.008360
# Epoch 349/1000 | lr=7.30e-06 | train_loss=0.008096 | val_loss=0.008384
# Epoch 350/1000 | lr=7.29e-06 | train_loss=0.008085 | val_loss=0.008361
# Epoch 351/1000 | lr=7.27e-06 | train_loss=0.008079 | val_loss=0.008362
# Epoch 352/1000 | lr=7.26e-06 | train_loss=0.008083 | val_loss=0.008352
# Epoch 353/1000 | lr=7.24e-06 | train_loss=0.008077 | val_loss=0.008344
# Epoch 354/1000 | lr=7.23e-06 | train_loss=0.008074 | val_loss=0.008339
# Epoch 355/1000 | lr=7.22e-06 | train_loss=0.008071 | val_loss=0.008335
# Epoch 356/1000 | lr=7.20e-06 | train_loss=0.008071 | val_loss=0.008338
# Epoch 357/1000 | lr=7.19e-06 | train_loss=0.008070 | val_loss=0.008334
# Epoch 358/1000 | lr=7.17e-06 | train_loss=0.008068 | val_loss=0.008340
# Epoch 359/1000 | lr=7.16e-06 | train_loss=0.008072 | val_loss=0.008332
# Epoch 360/1000 | lr=7.15e-06 | train_loss=0.008072 | val_loss=0.008383
# Epoch 361/1000 | lr=7.13e-06 | train_loss=0.008089 | val_loss=0.008399
# Epoch 362/1000 | lr=7.12e-06 | train_loss=0.008143 | val_loss=0.008374
# Epoch 363/1000 | lr=7.10e-06 | train_loss=0.008106 | val_loss=0.008361
# Epoch 364/1000 | lr=7.09e-06 | train_loss=0.008079 | val_loss=0.008427
# Epoch 365/1000 | lr=7.07e-06 | train_loss=0.008117 | val_loss=0.008354
# Epoch 366/1000 | lr=7.06e-06 | train_loss=0.008115 | val_loss=0.008550
# Epoch 367/1000 | lr=7.05e-06 | train_loss=0.008181 | val_loss=0.008429
# Epoch 368/1000 | lr=7.03e-06 | train_loss=0.008106 | val_loss=0.008573
# Epoch 369/1000 | lr=7.02e-06 | train_loss=0.008134 | val_loss=0.008381
# Epoch 370/1000 | lr=7.00e-06 | train_loss=0.008090 | val_loss=0.008402
# Epoch 371/1000 | lr=6.99e-06 | train_loss=0.008113 | val_loss=0.008372
# Epoch 372/1000 | lr=6.97e-06 | train_loss=0.008103 | val_loss=0.008513
# Epoch 373/1000 | lr=6.96e-06 | train_loss=0.008169 | val_loss=0.008456
# Epoch 374/1000 | lr=6.95e-06 | train_loss=0.008112 | val_loss=0.008480
# Epoch 375/1000 | lr=6.93e-06 | train_loss=0.008101 | val_loss=0.008343
# Epoch 376/1000 | lr=6.92e-06 | train_loss=0.008065 | val_loss=0.008326
# Epoch 377/1000 | lr=6.90e-06 | train_loss=0.008057 | val_loss=0.008325
# Epoch 378/1000 | lr=6.89e-06 | train_loss=0.008057 | val_loss=0.008321
# Epoch 379/1000 | lr=6.87e-06 | train_loss=0.008054 | val_loss=0.008320
# Epoch 380/1000 | lr=6.86e-06 | train_loss=0.008054 | val_loss=0.008320
# Epoch 381/1000 | lr=6.84e-06 | train_loss=0.008054 | val_loss=0.008333
# Epoch 382/1000 | lr=6.83e-06 | train_loss=0.008057 | val_loss=0.008319
# Epoch 383/1000 | lr=6.81e-06 | train_loss=0.008053 | val_loss=0.008323
# Epoch 384/1000 | lr=6.80e-06 | train_loss=0.008054 | val_loss=0.008326
# Epoch 385/1000 | lr=6.79e-06 | train_loss=0.008056 | val_loss=0.008321
# Epoch 386/1000 | lr=6.77e-06 | train_loss=0.008053 | val_loss=0.008342
# Epoch 387/1000 | lr=6.76e-06 | train_loss=0.008059 | val_loss=0.008328
# Epoch 388/1000 | lr=6.74e-06 | train_loss=0.008055 | val_loss=0.008318
# Epoch 389/1000 | lr=6.73e-06 | train_loss=0.008049 | val_loss=0.008319
# Epoch 390/1000 | lr=6.71e-06 | train_loss=0.008049 | val_loss=0.008316
# Epoch 391/1000 | lr=6.70e-06 | train_loss=0.008047 | val_loss=0.008315
# Epoch 392/1000 | lr=6.68e-06 | train_loss=0.008046 | val_loss=0.008318
# Epoch 393/1000 | lr=6.67e-06 | train_loss=0.008047 | val_loss=0.008317
# Epoch 394/1000 | lr=6.65e-06 | train_loss=0.008046 | val_loss=0.008324
# Epoch 395/1000 | lr=6.64e-06 | train_loss=0.008047 | val_loss=0.008323
# Epoch 396/1000 | lr=6.62e-06 | train_loss=0.008048 | val_loss=0.008313
# Epoch 397/1000 | lr=6.61e-06 | train_loss=0.008044 | val_loss=0.008312
# Epoch 398/1000 | lr=6.59e-06 | train_loss=0.008044 | val_loss=0.008312
# Epoch 399/1000 | lr=6.58e-06 | train_loss=0.008045 | val_loss=0.008329
# Epoch 400/1000 | lr=6.56e-06 | train_loss=0.008048 | val_loss=0.008324
# Epoch 401/1000 | lr=6.55e-06 | train_loss=0.008047 | val_loss=0.008321
# Epoch 402/1000 | lr=6.53e-06 | train_loss=0.008045 | val_loss=0.008309
# Epoch 403/1000 | lr=6.52e-06 | train_loss=0.008041 | val_loss=0.008307
# Epoch 404/1000 | lr=6.50e-06 | train_loss=0.008039 | val_loss=0.008308
# Epoch 405/1000 | lr=6.49e-06 | train_loss=0.008039 | val_loss=0.008317
# Epoch 406/1000 | lr=6.47e-06 | train_loss=0.008042 | val_loss=0.008316
# Epoch 407/1000 | lr=6.46e-06 | train_loss=0.008045 | val_loss=0.008321
# Epoch 408/1000 | lr=6.44e-06 | train_loss=0.008045 | val_loss=0.008318
# Epoch 409/1000 | lr=6.43e-06 | train_loss=0.008046 | val_loss=0.008320
# Epoch 410/1000 | lr=6.41e-06 | train_loss=0.008052 | val_loss=0.008341
# Epoch 411/1000 | lr=6.40e-06 | train_loss=0.008068 | val_loss=0.008312
# Epoch 412/1000 | lr=6.38e-06 | train_loss=0.008047 | val_loss=0.008383
# Epoch 413/1000 | lr=6.37e-06 | train_loss=0.008087 | val_loss=0.008329
# Epoch 414/1000 | lr=6.35e-06 | train_loss=0.008048 | val_loss=0.008385
# Epoch 415/1000 | lr=6.34e-06 | train_loss=0.008088 | val_loss=0.008340
# Epoch 416/1000 | lr=6.32e-06 | train_loss=0.008054 | val_loss=0.008314
# Epoch 417/1000 | lr=6.31e-06 | train_loss=0.008058 | val_loss=0.008304
# Epoch 418/1000 | lr=6.29e-06 | train_loss=0.008048 | val_loss=0.008314
# Epoch 419/1000 | lr=6.28e-06 | train_loss=0.008057 | val_loss=0.008304
# Epoch 420/1000 | lr=6.26e-06 | train_loss=0.008044 | val_loss=0.008327
# Epoch 421/1000 | lr=6.25e-06 | train_loss=0.008065 | val_loss=0.008299
# Epoch 422/1000 | lr=6.23e-06 | train_loss=0.008043 | val_loss=0.008300
# Epoch 423/1000 | lr=6.22e-06 | train_loss=0.008036 | val_loss=0.008327
# Epoch 424/1000 | lr=6.20e-06 | train_loss=0.008048 | val_loss=0.008302
# Epoch 425/1000 | lr=6.19e-06 | train_loss=0.008031 | val_loss=0.008306
# Epoch 426/1000 | lr=6.17e-06 | train_loss=0.008035 | val_loss=0.008303
# Epoch 427/1000 | lr=6.16e-06 | train_loss=0.008039 | val_loss=0.008304
# Epoch 428/1000 | lr=6.14e-06 | train_loss=0.008036 | val_loss=0.008302
# Epoch 429/1000 | lr=6.13e-06 | train_loss=0.008033 | val_loss=0.008329
# Epoch 430/1000 | lr=6.11e-06 | train_loss=0.008039 | val_loss=0.008325
# Epoch 431/1000 | lr=6.09e-06 | train_loss=0.008039 | val_loss=0.008295
# Epoch 432/1000 | lr=6.08e-06 | train_loss=0.008027 | val_loss=0.008293
# Epoch 433/1000 | lr=6.06e-06 | train_loss=0.008025 | val_loss=0.008295
# Epoch 434/1000 | lr=6.05e-06 | train_loss=0.008027 | val_loss=0.008296
# Epoch 435/1000 | lr=6.03e-06 | train_loss=0.008029 | val_loss=0.008311
# Epoch 436/1000 | lr=6.02e-06 | train_loss=0.008045 | val_loss=0.008300
# Epoch 437/1000 | lr=6.00e-06 | train_loss=0.008049 | val_loss=0.008375
# Epoch 438/1000 | lr=5.99e-06 | train_loss=0.008073 | val_loss=0.008411
# Epoch 439/1000 | lr=5.97e-06 | train_loss=0.008094 | val_loss=0.008577
# Epoch 440/1000 | lr=5.96e-06 | train_loss=0.008507 | val_loss=0.010308
# Epoch 441/1000 | lr=5.94e-06 | train_loss=0.009095 | val_loss=0.008411
# Epoch 442/1000 | lr=5.93e-06 | train_loss=0.008571 | val_loss=0.008593
# Epoch 443/1000 | lr=5.91e-06 | train_loss=0.008276 | val_loss=0.008481
# Epoch 444/1000 | lr=5.89e-06 | train_loss=0.008108 | val_loss=0.008351
# Epoch 445/1000 | lr=5.88e-06 | train_loss=0.008086 | val_loss=0.008318
# Epoch 446/1000 | lr=5.86e-06 | train_loss=0.008043 | val_loss=0.008352
# Epoch 447/1000 | lr=5.85e-06 | train_loss=0.008043 | val_loss=0.008315
# Epoch 448/1000 | lr=5.83e-06 | train_loss=0.008032 | val_loss=0.008302
# Epoch 449/1000 | lr=5.82e-06 | train_loss=0.008027 | val_loss=0.008303
# Epoch 450/1000 | lr=5.80e-06 | train_loss=0.008027 | val_loss=0.008286
# Epoch 451/1000 | lr=5.79e-06 | train_loss=0.008020 | val_loss=0.008284
# Epoch 452/1000 | lr=5.77e-06 | train_loss=0.008020 | val_loss=0.008287
# Epoch 453/1000 | lr=5.76e-06 | train_loss=0.008019 | val_loss=0.008288
# Epoch 454/1000 | lr=5.74e-06 | train_loss=0.008022 | val_loss=0.008285
# Epoch 455/1000 | lr=5.72e-06 | train_loss=0.008019 | val_loss=0.008289
# Epoch 456/1000 | lr=5.71e-06 | train_loss=0.008019 | val_loss=0.008285
# Epoch 457/1000 | lr=5.69e-06 | train_loss=0.008018 | val_loss=0.008287
# Epoch 458/1000 | lr=5.68e-06 | train_loss=0.008019 | val_loss=0.008289
# Epoch 459/1000 | lr=5.66e-06 | train_loss=0.008019 | val_loss=0.008291
# Epoch 460/1000 | lr=5.65e-06 | train_loss=0.008020 | val_loss=0.008280
# Epoch 461/1000 | lr=5.63e-06 | train_loss=0.008015 | val_loss=0.008286
# Epoch 462/1000 | lr=5.62e-06 | train_loss=0.008016 | val_loss=0.008278
# Epoch 463/1000 | lr=5.60e-06 | train_loss=0.008014 | val_loss=0.008280
# Epoch 464/1000 | lr=5.58e-06 | train_loss=0.008015 | val_loss=0.008276
# Epoch 465/1000 | lr=5.57e-06 | train_loss=0.008012 | val_loss=0.008277
# Epoch 466/1000 | lr=5.55e-06 | train_loss=0.008012 | val_loss=0.008275
# Epoch 467/1000 | lr=5.54e-06 | train_loss=0.008011 | val_loss=0.008274
# Epoch 468/1000 | lr=5.52e-06 | train_loss=0.008011 | val_loss=0.008274
# Epoch 469/1000 | lr=5.51e-06 | train_loss=0.008011 | val_loss=0.008273
# Epoch 470/1000 | lr=5.49e-06 | train_loss=0.008010 | val_loss=0.008272
# Epoch 471/1000 | lr=5.48e-06 | train_loss=0.008009 | val_loss=0.008272
# Epoch 472/1000 | lr=5.46e-06 | train_loss=0.008009 | val_loss=0.008272
# Epoch 473/1000 | lr=5.44e-06 | train_loss=0.008008 | val_loss=0.008272
# Epoch 474/1000 | lr=5.43e-06 | train_loss=0.008008 | val_loss=0.008271
# Epoch 475/1000 | lr=5.41e-06 | train_loss=0.008008 | val_loss=0.008272
# Epoch 476/1000 | lr=5.40e-06 | train_loss=0.008008 | val_loss=0.008271
# Epoch 477/1000 | lr=5.38e-06 | train_loss=0.008007 | val_loss=0.008271
# Epoch 478/1000 | lr=5.37e-06 | train_loss=0.008008 | val_loss=0.008277
# Epoch 479/1000 | lr=5.35e-06 | train_loss=0.008008 | val_loss=0.008274
# Epoch 480/1000 | lr=5.33e-06 | train_loss=0.008008 | val_loss=0.008272
# Epoch 481/1000 | lr=5.32e-06 | train_loss=0.008007 | val_loss=0.008271
# Epoch 482/1000 | lr=5.30e-06 | train_loss=0.008007 | val_loss=0.008267
# Epoch 483/1000 | lr=5.29e-06 | train_loss=0.008005 | val_loss=0.008267
# Epoch 484/1000 | lr=5.27e-06 | train_loss=0.008005 | val_loss=0.008266
# Epoch 485/1000 | lr=5.26e-06 | train_loss=0.008004 | val_loss=0.008266
# Epoch 486/1000 | lr=5.24e-06 | train_loss=0.008004 | val_loss=0.008267
# Epoch 487/1000 | lr=5.22e-06 | train_loss=0.008004 | val_loss=0.008267
# Epoch 488/1000 | lr=5.21e-06 | train_loss=0.008005 | val_loss=0.008266
# Epoch 489/1000 | lr=5.19e-06 | train_loss=0.008004 | val_loss=0.008274
# Epoch 490/1000 | lr=5.18e-06 | train_loss=0.008007 | val_loss=0.008265
# Epoch 491/1000 | lr=5.16e-06 | train_loss=0.008004 | val_loss=0.008263
# Epoch 492/1000 | lr=5.15e-06 | train_loss=0.008002 | val_loss=0.008263
# Epoch 493/1000 | lr=5.13e-06 | train_loss=0.008002 | val_loss=0.008261
# Epoch 494/1000 | lr=5.11e-06 | train_loss=0.008000 | val_loss=0.008260
# Epoch 495/1000 | lr=5.10e-06 | train_loss=0.008000 | val_loss=0.008260
# Epoch 496/1000 | lr=5.08e-06 | train_loss=0.007999 | val_loss=0.008259
# Epoch 497/1000 | lr=5.07e-06 | train_loss=0.007999 | val_loss=0.008260
# Epoch 498/1000 | lr=5.05e-06 | train_loss=0.007999 | val_loss=0.008260
# Epoch 499/1000 | lr=5.04e-06 | train_loss=0.007999 | val_loss=0.008258
# Epoch 500/1000 | lr=5.02e-06 | train_loss=0.007998 | val_loss=0.008257
# Epoch 501/1000 | lr=5.00e-06 | train_loss=0.007998 | val_loss=0.008258
# Epoch 502/1000 | lr=4.99e-06 | train_loss=0.007997 | val_loss=0.008261
# Epoch 503/1000 | lr=4.97e-06 | train_loss=0.007998 | val_loss=0.008258
# Epoch 504/1000 | lr=4.96e-06 | train_loss=0.007997 | val_loss=0.008255
# Epoch 505/1000 | lr=4.94e-06 | train_loss=0.007996 | val_loss=0.008255
# Epoch 506/1000 | lr=4.93e-06 | train_loss=0.007995 | val_loss=0.008257
# Epoch 507/1000 | lr=4.91e-06 | train_loss=0.007997 | val_loss=0.008256
# Epoch 508/1000 | lr=4.90e-06 | train_loss=0.007995 | val_loss=0.008256
# Epoch 509/1000 | lr=4.88e-06 | train_loss=0.007996 | val_loss=0.008256
# Epoch 510/1000 | lr=4.86e-06 | train_loss=0.007995 | val_loss=0.008254
# Epoch 511/1000 | lr=4.85e-06 | train_loss=0.007994 | val_loss=0.008254
# Epoch 512/1000 | lr=4.83e-06 | train_loss=0.007995 | val_loss=0.008254
# Epoch 513/1000 | lr=4.82e-06 | train_loss=0.007995 | val_loss=0.008258
# Epoch 514/1000 | lr=4.80e-06 | train_loss=0.007996 | val_loss=0.008253
# Epoch 515/1000 | lr=4.79e-06 | train_loss=0.007994 | val_loss=0.008251
# Epoch 516/1000 | lr=4.77e-06 | train_loss=0.007992 | val_loss=0.008253
# Epoch 517/1000 | lr=4.75e-06 | train_loss=0.007993 | val_loss=0.008258
# Epoch 518/1000 | lr=4.74e-06 | train_loss=0.007994 | val_loss=0.008256
# Epoch 519/1000 | lr=4.72e-06 | train_loss=0.007996 | val_loss=0.008258
# Epoch 520/1000 | lr=4.71e-06 | train_loss=0.008009 | val_loss=0.008260
# Epoch 521/1000 | lr=4.69e-06 | train_loss=0.008001 | val_loss=0.008253
# Epoch 522/1000 | lr=4.68e-06 | train_loss=0.007996 | val_loss=0.008255
# Epoch 523/1000 | lr=4.66e-06 | train_loss=0.007993 | val_loss=0.008261
# Epoch 524/1000 | lr=4.64e-06 | train_loss=0.007994 | val_loss=0.008258
# Epoch 525/1000 | lr=4.63e-06 | train_loss=0.007995 | val_loss=0.008251
# Epoch 526/1000 | lr=4.61e-06 | train_loss=0.007991 | val_loss=0.008258
# Epoch 527/1000 | lr=4.60e-06 | train_loss=0.007992 | val_loss=0.008252
# Epoch 528/1000 | lr=4.58e-06 | train_loss=0.007989 | val_loss=0.008248
# Epoch 529/1000 | lr=4.57e-06 | train_loss=0.007987 | val_loss=0.008249
# Epoch 530/1000 | lr=4.55e-06 | train_loss=0.007987 | val_loss=0.008247
# Epoch 531/1000 | lr=4.53e-06 | train_loss=0.007986 | val_loss=0.008254
# Epoch 532/1000 | lr=4.52e-06 | train_loss=0.007989 | val_loss=0.008250
# Epoch 533/1000 | lr=4.50e-06 | train_loss=0.007987 | val_loss=0.008247
# Epoch 534/1000 | lr=4.49e-06 | train_loss=0.007986 | val_loss=0.008251
# Epoch 535/1000 | lr=4.47e-06 | train_loss=0.007987 | val_loss=0.008252
# Epoch 536/1000 | lr=4.46e-06 | train_loss=0.007988 | val_loss=0.008252
# Epoch 537/1000 | lr=4.44e-06 | train_loss=0.007986 | val_loss=0.008251
# Epoch 538/1000 | lr=4.43e-06 | train_loss=0.007985 | val_loss=0.008252
# Epoch 539/1000 | lr=4.41e-06 | train_loss=0.007985 | val_loss=0.008248
# Epoch 540/1000 | lr=4.39e-06 | train_loss=0.007985 | val_loss=0.008250
# Epoch 541/1000 | lr=4.38e-06 | train_loss=0.007985 | val_loss=0.008244
# Epoch 542/1000 | lr=4.36e-06 | train_loss=0.007982 | val_loss=0.008241
# Epoch 543/1000 | lr=4.35e-06 | train_loss=0.007981 | val_loss=0.008240
# Epoch 544/1000 | lr=4.33e-06 | train_loss=0.007980 | val_loss=0.008240
# Epoch 545/1000 | lr=4.32e-06 | train_loss=0.007980 | val_loss=0.008240
# Epoch 546/1000 | lr=4.30e-06 | train_loss=0.007980 | val_loss=0.008240
# Epoch 547/1000 | lr=4.29e-06 | train_loss=0.007980 | val_loss=0.008240
# Epoch 548/1000 | lr=4.27e-06 | train_loss=0.007980 | val_loss=0.008242
# Epoch 549/1000 | lr=4.25e-06 | train_loss=0.007980 | val_loss=0.008239
# Epoch 550/1000 | lr=4.24e-06 | train_loss=0.007979 | val_loss=0.008238
# Epoch 551/1000 | lr=4.22e-06 | train_loss=0.007978 | val_loss=0.008238
# Epoch 552/1000 | lr=4.21e-06 | train_loss=0.007978 | val_loss=0.008240
# Epoch 553/1000 | lr=4.19e-06 | train_loss=0.007978 | val_loss=0.008241
# Epoch 554/1000 | lr=4.18e-06 | train_loss=0.007978 | val_loss=0.008240
# Epoch 555/1000 | lr=4.16e-06 | train_loss=0.007978 | val_loss=0.008237
# Epoch 556/1000 | lr=4.15e-06 | train_loss=0.007976 | val_loss=0.008236
# Epoch 557/1000 | lr=4.13e-06 | train_loss=0.007976 | val_loss=0.008236
# Epoch 558/1000 | lr=4.12e-06 | train_loss=0.007976 | val_loss=0.008235
# Epoch 559/1000 | lr=4.10e-06 | train_loss=0.007976 | val_loss=0.008236
# Epoch 560/1000 | lr=4.08e-06 | train_loss=0.007975 | val_loss=0.008240
# Epoch 561/1000 | lr=4.07e-06 | train_loss=0.007977 | val_loss=0.008240
# Epoch 562/1000 | lr=4.05e-06 | train_loss=0.007977 | val_loss=0.008235
# Epoch 563/1000 | lr=4.04e-06 | train_loss=0.007975 | val_loss=0.008233
# Epoch 564/1000 | lr=4.02e-06 | train_loss=0.007974 | val_loss=0.008233
# Epoch 565/1000 | lr=4.01e-06 | train_loss=0.007974 | val_loss=0.008251
# Epoch 566/1000 | lr=3.99e-06 | train_loss=0.007979 | val_loss=0.008238
# Epoch 567/1000 | lr=3.98e-06 | train_loss=0.007976 | val_loss=0.008236
# Epoch 568/1000 | lr=3.96e-06 | train_loss=0.007977 | val_loss=0.008231
# Epoch 569/1000 | lr=3.95e-06 | train_loss=0.007973 | val_loss=0.008233
# Epoch 570/1000 | lr=3.93e-06 | train_loss=0.007973 | val_loss=0.008231
# Epoch 571/1000 | lr=3.92e-06 | train_loss=0.007971 | val_loss=0.008232
# Epoch 572/1000 | lr=3.90e-06 | train_loss=0.007972 | val_loss=0.008231
# Epoch 573/1000 | lr=3.88e-06 | train_loss=0.007971 | val_loss=0.008231
# Epoch 574/1000 | lr=3.87e-06 | train_loss=0.007971 | val_loss=0.008230
# Epoch 575/1000 | lr=3.85e-06 | train_loss=0.007970 | val_loss=0.008230
# Epoch 576/1000 | lr=3.84e-06 | train_loss=0.007970 | val_loss=0.008230
# Epoch 577/1000 | lr=3.82e-06 | train_loss=0.007970 | val_loss=0.008229
# Epoch 578/1000 | lr=3.81e-06 | train_loss=0.007970 | val_loss=0.008227
# Epoch 579/1000 | lr=3.79e-06 | train_loss=0.007969 | val_loss=0.008227
# Epoch 580/1000 | lr=3.78e-06 | train_loss=0.007968 | val_loss=0.008227
# Epoch 581/1000 | lr=3.76e-06 | train_loss=0.007968 | val_loss=0.008226
# Epoch 582/1000 | lr=3.75e-06 | train_loss=0.007968 | val_loss=0.008226
# Epoch 583/1000 | lr=3.73e-06 | train_loss=0.007967 | val_loss=0.008226
# Epoch 584/1000 | lr=3.72e-06 | train_loss=0.007967 | val_loss=0.008226
# Epoch 585/1000 | lr=3.70e-06 | train_loss=0.007967 | val_loss=0.008225
# Epoch 586/1000 | lr=3.69e-06 | train_loss=0.007967 | val_loss=0.008227
# Epoch 587/1000 | lr=3.67e-06 | train_loss=0.007967 | val_loss=0.008226
# Epoch 588/1000 | lr=3.66e-06 | train_loss=0.007966 | val_loss=0.008232
# Epoch 589/1000 | lr=3.64e-06 | train_loss=0.007970 | val_loss=0.008232
# Epoch 590/1000 | lr=3.63e-06 | train_loss=0.007971 | val_loss=0.008237
# Epoch 591/1000 | lr=3.61e-06 | train_loss=0.007973 | val_loss=0.008225
# Epoch 592/1000 | lr=3.60e-06 | train_loss=0.007966 | val_loss=0.008223
# Epoch 593/1000 | lr=3.58e-06 | train_loss=0.007965 | val_loss=0.008223
# Epoch 594/1000 | lr=3.57e-06 | train_loss=0.007965 | val_loss=0.008224
# Epoch 595/1000 | lr=3.55e-06 | train_loss=0.007964 | val_loss=0.008222
# Epoch 596/1000 | lr=3.54e-06 | train_loss=0.007964 | val_loss=0.008223
# Epoch 597/1000 | lr=3.52e-06 | train_loss=0.007964 | val_loss=0.008221
# Epoch 598/1000 | lr=3.51e-06 | train_loss=0.007963 | val_loss=0.008222
# Epoch 599/1000 | lr=3.49e-06 | train_loss=0.007963 | val_loss=0.008223
# Epoch 600/1000 | lr=3.48e-06 | train_loss=0.007964 | val_loss=0.008222
# Epoch 601/1000 | lr=3.46e-06 | train_loss=0.007963 | val_loss=0.008228
# Epoch 602/1000 | lr=3.45e-06 | train_loss=0.007964 | val_loss=0.008221
# Epoch 603/1000 | lr=3.43e-06 | train_loss=0.007962 | val_loss=0.008221
# Epoch 604/1000 | lr=3.42e-06 | train_loss=0.007962 | val_loss=0.008226
# Epoch 605/1000 | lr=3.40e-06 | train_loss=0.007963 | val_loss=0.008229
# Epoch 606/1000 | lr=3.39e-06 | train_loss=0.007964 | val_loss=0.008223
# Epoch 607/1000 | lr=3.37e-06 | train_loss=0.007962 | val_loss=0.008218
# Epoch 608/1000 | lr=3.36e-06 | train_loss=0.007960 | val_loss=0.008222
# Epoch 609/1000 | lr=3.34e-06 | train_loss=0.007962 | val_loss=0.008222
# Epoch 610/1000 | lr=3.33e-06 | train_loss=0.007962 | val_loss=0.008233
# Epoch 611/1000 | lr=3.31e-06 | train_loss=0.007964 | val_loss=0.008222
# Epoch 612/1000 | lr=3.30e-06 | train_loss=0.007962 | val_loss=0.008221
# Epoch 613/1000 | lr=3.28e-06 | train_loss=0.007962 | val_loss=0.008235
# Epoch 614/1000 | lr=3.27e-06 | train_loss=0.007964 | val_loss=0.008226
# Epoch 615/1000 | lr=3.25e-06 | train_loss=0.007963 | val_loss=0.008216
# Epoch 616/1000 | lr=3.24e-06 | train_loss=0.007959 | val_loss=0.008229
# Epoch 617/1000 | lr=3.22e-06 | train_loss=0.007963 | val_loss=0.008227
# Epoch 618/1000 | lr=3.21e-06 | train_loss=0.007963 | val_loss=0.008216
# Epoch 619/1000 | lr=3.20e-06 | train_loss=0.007959 | val_loss=0.008215
# Epoch 620/1000 | lr=3.18e-06 | train_loss=0.007957 | val_loss=0.008215
# Epoch 621/1000 | lr=3.17e-06 | train_loss=0.007957 | val_loss=0.008216
# Epoch 622/1000 | lr=3.15e-06 | train_loss=0.007956 | val_loss=0.008215
# Epoch 623/1000 | lr=3.14e-06 | train_loss=0.007956 | val_loss=0.008214
# Epoch 624/1000 | lr=3.12e-06 | train_loss=0.007955 | val_loss=0.008214
# Epoch 625/1000 | lr=3.11e-06 | train_loss=0.007955 | val_loss=0.008223
# Epoch 626/1000 | lr=3.09e-06 | train_loss=0.007958 | val_loss=0.008216
# Epoch 627/1000 | lr=3.08e-06 | train_loss=0.007956 | val_loss=0.008218
# Epoch 628/1000 | lr=3.06e-06 | train_loss=0.007957 | val_loss=0.008214
# Epoch 629/1000 | lr=3.05e-06 | train_loss=0.007957 | val_loss=0.008213
# Epoch 630/1000 | lr=3.04e-06 | train_loss=0.007955 | val_loss=0.008219
# Epoch 631/1000 | lr=3.02e-06 | train_loss=0.007957 | val_loss=0.008213
# Epoch 632/1000 | lr=3.01e-06 | train_loss=0.007954 | val_loss=0.008215
# Epoch 633/1000 | lr=2.99e-06 | train_loss=0.007954 | val_loss=0.008212
# Epoch 634/1000 | lr=2.98e-06 | train_loss=0.007953 | val_loss=0.008210
# Epoch 635/1000 | lr=2.96e-06 | train_loss=0.007953 | val_loss=0.008210
# Epoch 636/1000 | lr=2.95e-06 | train_loss=0.007953 | val_loss=0.008210
# Epoch 637/1000 | lr=2.94e-06 | train_loss=0.007952 | val_loss=0.008209
# Epoch 638/1000 | lr=2.92e-06 | train_loss=0.007951 | val_loss=0.008209
# Epoch 639/1000 | lr=2.91e-06 | train_loss=0.007951 | val_loss=0.008210
# Epoch 640/1000 | lr=2.89e-06 | train_loss=0.007952 | val_loss=0.008209
# Epoch 641/1000 | lr=2.88e-06 | train_loss=0.007951 | val_loss=0.008209
# Epoch 642/1000 | lr=2.86e-06 | train_loss=0.007951 | val_loss=0.008208
# Epoch 643/1000 | lr=2.85e-06 | train_loss=0.007950 | val_loss=0.008208
# Epoch 644/1000 | lr=2.84e-06 | train_loss=0.007950 | val_loss=0.008208
# Epoch 645/1000 | lr=2.82e-06 | train_loss=0.007949 | val_loss=0.008211
# Epoch 646/1000 | lr=2.81e-06 | train_loss=0.007951 | val_loss=0.008208
# Epoch 647/1000 | lr=2.79e-06 | train_loss=0.007949 | val_loss=0.008207
# Epoch 648/1000 | lr=2.78e-06 | train_loss=0.007949 | val_loss=0.008207
# Epoch 649/1000 | lr=2.77e-06 | train_loss=0.007949 | val_loss=0.008206
# Epoch 650/1000 | lr=2.75e-06 | train_loss=0.007948 | val_loss=0.008206
# Epoch 651/1000 | lr=2.74e-06 | train_loss=0.007948 | val_loss=0.008207
# Epoch 652/1000 | lr=2.72e-06 | train_loss=0.007948 | val_loss=0.008208
# Epoch 653/1000 | lr=2.71e-06 | train_loss=0.007949 | val_loss=0.008209
# Epoch 654/1000 | lr=2.70e-06 | train_loss=0.007950 | val_loss=0.008207
# Epoch 655/1000 | lr=2.68e-06 | train_loss=0.007949 | val_loss=0.008205
# Epoch 656/1000 | lr=2.67e-06 | train_loss=0.007947 | val_loss=0.008206
# Epoch 657/1000 | lr=2.65e-06 | train_loss=0.007947 | val_loss=0.008206
# Epoch 658/1000 | lr=2.64e-06 | train_loss=0.007947 | val_loss=0.008205
# Epoch 659/1000 | lr=2.63e-06 | train_loss=0.007947 | val_loss=0.008204
# Epoch 660/1000 | lr=2.61e-06 | train_loss=0.007946 | val_loss=0.008206
# Epoch 661/1000 | lr=2.60e-06 | train_loss=0.007947 | val_loss=0.008204
# Epoch 662/1000 | lr=2.58e-06 | train_loss=0.007946 | val_loss=0.008203
# Epoch 663/1000 | lr=2.57e-06 | train_loss=0.007945 | val_loss=0.008203
# Epoch 664/1000 | lr=2.56e-06 | train_loss=0.007945 | val_loss=0.008203
# Epoch 665/1000 | lr=2.54e-06 | train_loss=0.007945 | val_loss=0.008208
# Epoch 666/1000 | lr=2.53e-06 | train_loss=0.007946 | val_loss=0.008204
# Epoch 667/1000 | lr=2.52e-06 | train_loss=0.007946 | val_loss=0.008202
# Epoch 668/1000 | lr=2.50e-06 | train_loss=0.007945 | val_loss=0.008205
# Epoch 669/1000 | lr=2.49e-06 | train_loss=0.007945 | val_loss=0.008204
# Epoch 670/1000 | lr=2.48e-06 | train_loss=0.007944 | val_loss=0.008203
# Epoch 671/1000 | lr=2.46e-06 | train_loss=0.007944 | val_loss=0.008202
# Epoch 672/1000 | lr=2.45e-06 | train_loss=0.007944 | val_loss=0.008203
# Epoch 673/1000 | lr=2.44e-06 | train_loss=0.007944 | val_loss=0.008203
# ...
# Epoch 780/1000 | lr=1.17e-06 | train_loss=0.007927 | val_loss=0.008184
# Epoch 781/1000 | lr=1.16e-06 | train_loss=0.007927 | val_loss=0.008184
# Epoch 782/1000 | lr=1.15e-06 | train_loss=0.007927 | val_loss=0.008184
# Epoch 783/1000 | lr=1.14e-06 | train_loss=0.007927 | val_loss=0.008184
# Epoch 784/1000 | lr=1.13e-06 | train_loss=0.007926 | val_loss=0.008184
# Epoch 785/1000 | lr=1.12e-06 | train_loss=0.007926 | val_loss=0.008184
# Epoch 786/1000 | lr=1.11e-06 | train_loss=0.007927 | val_loss=0.008183
# Epoch 787/1000 | lr=1.10e-06 | train_loss=0.007926 | val_loss=0.008184
# Epoch 788/1000 | lr=1.09e-06 | train_loss=0.007926 | val_loss=0.008183
# Epoch 789/1000 | lr=1.08e-06 | train_loss=0.007926 | val_loss=0.008183
# Epoch 790/1000 | lr=1.07e-06 | train_loss=0.007926 | val_loss=0.008183
# Epoch 791/1000 | lr=1.06e-06 | train_loss=0.007926 | val_loss=0.008183
# Epoch 792/1000 | lr=1.05e-06 | train_loss=0.007926 | val_loss=0.008183
# Epoch 793/1000 | lr=1.04e-06 | train_loss=0.007926 | val_loss=0.008183
# Epoch 794/1000 | lr=1.03e-06 | train_loss=0.007926 | val_loss=0.008183
# Epoch 795/1000 | lr=1.02e-06 | train_loss=0.007925 | val_loss=0.008182
# Epoch 796/1000 | lr=1.01e-06 | train_loss=0.007925 | val_loss=0.008183
# Epoch 797/1000 | lr=1.00e-06 | train_loss=0.007925 | val_loss=0.008182
# Epoch 798/1000 | lr=9.92e-07 | train_loss=0.007925 | val_loss=0.008182
# Epoch 799/1000 | lr=9.82e-07 | train_loss=0.007925 | val_loss=0.008182
# Epoch 800/1000 | lr=9.73e-07 | train_loss=0.007925 | val_loss=0.008182
# Epoch 801/1000 | lr=9.64e-07 | train_loss=0.007925 | val_loss=0.008182
# Epoch 802/1000 | lr=9.55e-07 | train_loss=0.007925 | val_loss=0.008183
# Epoch 803/1000 | lr=9.46e-07 | train_loss=0.007925 | val_loss=0.008182
# Epoch 804/1000 | lr=9.36e-07 | train_loss=0.007925 | val_loss=0.008183
# Epoch 805/1000 | lr=9.27e-07 | train_loss=0.007925 | val_loss=0.008181
# Epoch 806/1000 | lr=9.18e-07 | train_loss=0.007925 | val_loss=0.008182
# Epoch 807/1000 | lr=9.09e-07 | train_loss=0.007925 | val_loss=0.008182
# Epoch 808/1000 | lr=9.00e-07 | train_loss=0.007925 | val_loss=0.008182
# Epoch 809/1000 | lr=8.91e-07 | train_loss=0.007925 | val_loss=0.008182
# Epoch 810/1000 | lr=8.83e-07 | train_loss=0.007925 | val_loss=0.008182
# Epoch 811/1000 | lr=8.74e-07 | train_loss=0.007924 | val_loss=0.008181
# Epoch 812/1000 | lr=8.65e-07 | train_loss=0.007924 | val_loss=0.008181
# Epoch 813/1000 | lr=8.56e-07 | train_loss=0.007924 | val_loss=0.008181
# Epoch 814/1000 | lr=8.47e-07 | train_loss=0.007924 | val_loss=0.008181
# Epoch 815/1000 | lr=8.39e-07 | train_loss=0.007924 | val_loss=0.008181
# Epoch 816/1000 | lr=8.30e-07 | train_loss=0.007924 | val_loss=0.008180
# Epoch 817/1000 | lr=8.22e-07 | train_loss=0.007924 | val_loss=0.008181
# Epoch 818/1000 | lr=8.13e-07 | train_loss=0.007924 | val_loss=0.008181
# Epoch 819/1000 | lr=8.04e-07 | train_loss=0.007924 | val_loss=0.008180
# Epoch 820/1000 | lr=7.96e-07 | train_loss=0.007923 | val_loss=0.008180
# Epoch 821/1000 | lr=7.88e-07 | train_loss=0.007923 | val_loss=0.008180
# Epoch 822/1000 | lr=7.79e-07 | train_loss=0.007923 | val_loss=0.008180
# Epoch 823/1000 | lr=7.71e-07 | train_loss=0.007923 | val_loss=0.008180
# Epoch 824/1000 | lr=7.63e-07 | train_loss=0.007923 | val_loss=0.008180
# Epoch 825/1000 | lr=7.54e-07 | train_loss=0.007923 | val_loss=0.008180
# Epoch 826/1000 | lr=7.46e-07 | train_loss=0.007923 | val_loss=0.008180
# Epoch 827/1000 | lr=7.38e-07 | train_loss=0.007923 | val_loss=0.008179
# Epoch 828/1000 | lr=7.30e-07 | train_loss=0.007923 | val_loss=0.008179
# Epoch 829/1000 | lr=7.22e-07 | train_loss=0.007923 | val_loss=0.008180
# Epoch 830/1000 | lr=7.14e-07 | train_loss=0.007923 | val_loss=0.008180
# Epoch 831/1000 | lr=7.06e-07 | train_loss=0.007923 | val_loss=0.008179
# Epoch 832/1000 | lr=6.98e-07 | train_loss=0.007923 | val_loss=0.008179
# Epoch 833/1000 | lr=6.90e-07 | train_loss=0.007923 | val_loss=0.008179
# Epoch 834/1000 | lr=6.82e-07 | train_loss=0.007922 | val_loss=0.008179
# Epoch 835/1000 | lr=6.74e-07 | train_loss=0.007922 | val_loss=0.008179
# Epoch 836/1000 | lr=6.66e-07 | train_loss=0.007922 | val_loss=0.008179
# Epoch 837/1000 | lr=6.58e-07 | train_loss=0.007922 | val_loss=0.008179
# Epoch 838/1000 | lr=6.51e-07 | train_loss=0.007922 | val_loss=0.008179
# Epoch 839/1000 | lr=6.43e-07 | train_loss=0.007922 | val_loss=0.008179
# Epoch 840/1000 | lr=6.35e-07 | train_loss=0.007922 | val_loss=0.008179
# Epoch 841/1000 | lr=6.28e-07 | train_loss=0.007922 | val_loss=0.008179
# Epoch 842/1000 | lr=6.20e-07 | train_loss=0.007922 | val_loss=0.008179
# Epoch 843/1000 | lr=6.13e-07 | train_loss=0.007922 | val_loss=0.008179
# Epoch 844/1000 | lr=6.05e-07 | train_loss=0.007922 | val_loss=0.008179
# Epoch 845/1000 | lr=5.98e-07 | train_loss=0.007922 | val_loss=0.008179
# Epoch 846/1000 | lr=5.91e-07 | train_loss=0.007922 | val_loss=0.008178
# Epoch 847/1000 | lr=5.83e-07 | train_loss=0.007922 | val_loss=0.008179
# Epoch 848/1000 | lr=5.76e-07 | train_loss=0.007922 | val_loss=0.008179
# Epoch 849/1000 | lr=5.69e-07 | train_loss=0.007922 | val_loss=0.008179
# Epoch 850/1000 | lr=5.62e-07 | train_loss=0.007922 | val_loss=0.008178
# Epoch 851/1000 | lr=5.54e-07 | train_loss=0.007922 | val_loss=0.008179
# Epoch 852/1000 | lr=5.47e-07 | train_loss=0.007922 | val_loss=0.008178
# Epoch 853/1000 | lr=5.40e-07 | train_loss=0.007922 | val_loss=0.008179
# Epoch 854/1000 | lr=5.33e-07 | train_loss=0.007922 | val_loss=0.008178
# Epoch 855/1000 | lr=5.26e-07 | train_loss=0.007921 | val_loss=0.008178
# Epoch 856/1000 | lr=5.19e-07 | train_loss=0.007921 | val_loss=0.008178
# Epoch 857/1000 | lr=5.12e-07 | train_loss=0.007921 | val_loss=0.008178
# Epoch 858/1000 | lr=5.06e-07 | train_loss=0.007921 | val_loss=0.008178
# Epoch 859/1000 | lr=4.99e-07 | train_loss=0.007921 | val_loss=0.008178
# Epoch 860/1000 | lr=4.92e-07 | train_loss=0.007921 | val_loss=0.008178
# Epoch 861/1000 | lr=4.85e-07 | train_loss=0.007921 | val_loss=0.008178
# Epoch 862/1000 | lr=4.79e-07 | train_loss=0.007921 | val_loss=0.008178
# Epoch 863/1000 | lr=4.72e-07 | train_loss=0.007921 | val_loss=0.008178
# Epoch 864/1000 | lr=4.66e-07 | train_loss=0.007921 | val_loss=0.008178
# Epoch 865/1000 | lr=4.59e-07 | train_loss=0.007921 | val_loss=0.008178
# Epoch 866/1000 | lr=4.53e-07 | train_loss=0.007921 | val_loss=0.008179
# Epoch 867/1000 | lr=4.46e-07 | train_loss=0.007921 | val_loss=0.008178
# Epoch 868/1000 | lr=4.40e-07 | train_loss=0.007921 | val_loss=0.008178
# Epoch 869/1000 | lr=4.33e-07 | train_loss=0.007921 | val_loss=0.008178
# Epoch 870/1000 | lr=4.27e-07 | train_loss=0.007921 | val_loss=0.008178
# Epoch 871/1000 | lr=4.21e-07 | train_loss=0.007921 | val_loss=0.008178
# Epoch 872/1000 | lr=4.15e-07 | train_loss=0.007921 | val_loss=0.008178
# Epoch 873/1000 | lr=4.08e-07 | train_loss=0.007921 | val_loss=0.008178
# Epoch 874/1000 | lr=4.02e-07 | train_loss=0.007921 | val_loss=0.008178
# Epoch 875/1000 | lr=3.96e-07 | train_loss=0.007921 | val_loss=0.008177
# Epoch 876/1000 | lr=3.90e-07 | train_loss=0.007921 | val_loss=0.008177
# Epoch 877/1000 | lr=3.84e-07 | train_loss=0.007921 | val_loss=0.008178
# Epoch 878/1000 | lr=3.78e-07 | train_loss=0.007921 | val_loss=0.008178
# Epoch 879/1000 | lr=3.72e-07 | train_loss=0.007921 | val_loss=0.008177
# Epoch 880/1000 | lr=3.67e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 881/1000 | lr=3.61e-07 | train_loss=0.007920 | val_loss=0.008178
# Epoch 882/1000 | lr=3.55e-07 | train_loss=0.007921 | val_loss=0.008177
# Epoch 883/1000 | lr=3.49e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 884/1000 | lr=3.44e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 885/1000 | lr=3.38e-07 | train_loss=0.007921 | val_loss=0.008178
# Epoch 886/1000 | lr=3.32e-07 | train_loss=0.007921 | val_loss=0.008177
# Epoch 887/1000 | lr=3.27e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 888/1000 | lr=3.21e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 889/1000 | lr=3.16e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 890/1000 | lr=3.11e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 891/1000 | lr=3.05e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 892/1000 | lr=3.00e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 893/1000 | lr=2.95e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 894/1000 | lr=2.90e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 895/1000 | lr=2.84e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 896/1000 | lr=2.79e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 897/1000 | lr=2.74e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 898/1000 | lr=2.69e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 899/1000 | lr=2.64e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 900/1000 | lr=2.59e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 901/1000 | lr=2.54e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 902/1000 | lr=2.50e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 903/1000 | lr=2.45e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 904/1000 | lr=2.40e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 905/1000 | lr=2.35e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 906/1000 | lr=2.31e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 907/1000 | lr=2.26e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 908/1000 | lr=2.22e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 909/1000 | lr=2.17e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 910/1000 | lr=2.13e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 911/1000 | lr=2.08e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 912/1000 | lr=2.04e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 913/1000 | lr=2.00e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 914/1000 | lr=1.95e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 915/1000 | lr=1.91e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 916/1000 | lr=1.87e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 917/1000 | lr=1.83e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 918/1000 | lr=1.79e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 919/1000 | lr=1.75e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 920/1000 | lr=1.71e-07 | train_loss=0.007920 | val_loss=0.008176
# Epoch 921/1000 | lr=1.67e-07 | train_loss=0.007920 | val_loss=0.008176
# Epoch 922/1000 | lr=1.63e-07 | train_loss=0.007920 | val_loss=0.008176
# Epoch 923/1000 | lr=1.59e-07 | train_loss=0.007920 | val_loss=0.008177
# Epoch 924/1000 | lr=1.55e-07 | train_loss=0.007920 | val_loss=0.008176
# Epoch 925/1000 | lr=1.52e-07 | train_loss=0.007920 | val_loss=0.008176
# Epoch 926/1000 | lr=1.48e-07 | train_loss=0.007920 | val_loss=0.008176
# Epoch 927/1000 | lr=1.44e-07 | train_loss=0.007920 | val_loss=0.008176
# Epoch 928/1000 | lr=1.41e-07 | train_loss=0.007920 | val_loss=0.008176
# Epoch 929/1000 | lr=1.37e-07 | train_loss=0.007920 | val_loss=0.008176
# Epoch 930/1000 | lr=1.34e-07 | train_loss=0.007920 | val_loss=0.008176
# Epoch 931/1000 | lr=1.30e-07 | train_loss=0.007919 | val_loss=0.008176
# Epoch 932/1000 | lr=1.27e-07 | train_loss=0.007919 | val_loss=0.008176
# Epoch 933/1000 | lr=1.24e-07 | train_loss=0.007920 | val_loss=0.008176
# Epoch 934/1000 | lr=1.20e-07 | train_loss=0.007919 | val_loss=0.008176
# Epoch 935/1000 | lr=1.17e-07 | train_loss=0.007919 | val_loss=0.008176
# Epoch 936/1000 | lr=1.14e-07 | train_loss=0.007919 | val_loss=0.008176
# Epoch 937/1000 | lr=1.11e-07 | train_loss=0.007919 | val_loss=0.008176
# Epoch 938/1000 | lr=1.08e-07 | train_loss=0.007920 | val_loss=0.008176
# Epoch 939/1000 | lr=1.04e-07 | train_loss=0.007919 | val_loss=0.008176
# Epoch 940/1000 | lr=1.01e-07 | train_loss=0.007919 | val_loss=0.008176
# Epoch 941/1000 | lr=9.85e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 942/1000 | lr=9.56e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 943/1000 | lr=9.27e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 944/1000 | lr=8.99e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 945/1000 | lr=8.71e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 946/1000 | lr=8.44e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 947/1000 | lr=8.17e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 948/1000 | lr=7.91e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 949/1000 | lr=7.65e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 950/1000 | lr=7.40e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 951/1000 | lr=7.15e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 952/1000 | lr=6.91e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 953/1000 | lr=6.67e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 954/1000 | lr=6.44e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 955/1000 | lr=6.21e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 956/1000 | lr=5.98e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 957/1000 | lr=5.76e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 958/1000 | lr=5.55e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 959/1000 | lr=5.34e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 960/1000 | lr=5.14e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 961/1000 | lr=4.94e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 962/1000 | lr=4.74e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 963/1000 | lr=4.56e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 964/1000 | lr=4.37e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 965/1000 | lr=4.19e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 966/1000 | lr=4.02e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 967/1000 | lr=3.85e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 968/1000 | lr=3.68e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 969/1000 | lr=3.52e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 970/1000 | lr=3.37e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 971/1000 | lr=3.22e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 972/1000 | lr=3.07e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 973/1000 | lr=2.93e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 974/1000 | lr=2.80e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 975/1000 | lr=2.67e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 976/1000 | lr=2.54e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 977/1000 | lr=2.42e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 978/1000 | lr=2.30e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 979/1000 | lr=2.19e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 980/1000 | lr=2.09e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 981/1000 | lr=1.99e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 982/1000 | lr=1.89e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 983/1000 | lr=1.80e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 984/1000 | lr=1.71e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 985/1000 | lr=1.63e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 986/1000 | lr=1.55e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 987/1000 | lr=1.48e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 988/1000 | lr=1.42e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 989/1000 | lr=1.35e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 990/1000 | lr=1.30e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 991/1000 | lr=1.25e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 992/1000 | lr=1.20e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 993/1000 | lr=1.16e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 994/1000 | lr=1.12e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 995/1000 | lr=1.09e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 996/1000 | lr=1.06e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 997/1000 | lr=1.04e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 998/1000 | lr=1.02e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 999/1000 | lr=1.01e-08 | train_loss=0.007919 | val_loss=0.008176
# Epoch 1000/1000 | lr=1.00e-08 | train_loss=0.007919 | val_loss=0.008176
# Saved best model: /content/drive/MyDrive/best_models_tesi/linearAE/linearAE_005/linear_AE_best_linearAE_005.pt
# Best validation loss: 0.008176
# Saved training curve: /content/drive/MyDrive/best_models_tesi/linearAE/linearAE_005/linear_AE_training_curve_linearAE_005.png

# %% [markdown]
# ## Step 6: Matrix-Level Reconstruction Visualization
# Show the same reconstruction plots used in the PCA notebook: clustered heatmaps and standard heatmaps (original, reconstructed, error).

# %%
recon_corr = reconstruct_matrices(model, x_test, n_assets=n_assets)

SAMPLE_IDX = 0

if not (0 <= SAMPLE_IDX < test_np.shape[0]):
    raise ValueError(f'SAMPLE_IDX must be in [0, {test_np.shape[0] - 1}]')

orig_mat = test_np[SAMPLE_IDX]
recon_mat = recon_corr[SAMPLE_IDX]
err_mat = recon_mat - orig_mat

print(f"Original Matrix:\n{orig_mat[:5, :5]}")  # Print the top-left 5x5 block of the original matrix for inspection
print(f"Reconstructed Matrix:\n{recon_mat[:5, :5]}")  # Print the top-left 5x5 block of the reconstructed matrix for inspection
print(f"Error Matrix:\n{err_mat[:5, :5]}")  # Print the top-left 5x5 block of the error matrix for inspection

mse_sample = float(np.mean((recon_mat - orig_mat) ** 2))
mae_sample = float(np.mean(np.abs(recon_mat - orig_mat)))
fro_sample = float(np.linalg.norm(recon_mat - orig_mat, ord='fro'))

print(f'Sample index: {SAMPLE_IDX}')
print(f'MSE: {mse_sample:.6f} | MAE: {mae_sample:.6f} | Frobenius: {fro_sample:.6f}')
print(f'Error range - Min: {err_mat.min():.6f} | Max: {err_mat.max():.6f}')

heatmap_base_dir = run_output_dir / 'heatmaps'
heatmap_base_dir.mkdir(parents=True, exist_ok=True)
heatmap_dir = heatmap_base_dir / f'idx{SAMPLE_IDX}'
heatmap_dir.mkdir(parents=True, exist_ok=True)

shared_cmap = 'coolwarm'
err_abs_max = float(np.max(np.abs(err_mat)))
if err_abs_max == 0:
    err_abs_max = 1e-6

# Build a single cluster ordering from the original matrix and reuse it for all three panels.
cluster_ref = sns.clustermap(
    orig_mat,
    vmin=-1,
    vmax=1,
    cmap=shared_cmap,
    linewidths=0,
    figsize=(8, 8),
    cbar_kws={'label': 'Correlation'},
)
row_order = cluster_ref.dendrogram_row.reordered_ind
col_order = cluster_ref.dendrogram_col.reordered_ind
plt.close(cluster_ref.fig)

orig_mat_clustered = orig_mat[np.ix_(row_order, col_order)]
recon_mat_clustered = recon_mat[np.ix_(row_order, col_order)]
err_mat_clustered = err_mat[np.ix_(row_order, col_order)]

fig_cluster, axes_cluster = plt.subplots(1, 3, figsize=(18, 5))

sns.heatmap(
    orig_mat_clustered,
    ax=axes_cluster[0],
    vmin=-1,
    vmax=1,
    cmap=shared_cmap,
    square=True,
)
axes_cluster[0].set_title('Original Matrix (Clustered Order)')

sns.heatmap(
    recon_mat_clustered,
    ax=axes_cluster[1],
    vmin=-1,
    vmax=1,
    cmap=shared_cmap,
    square=True,
)
axes_cluster[1].set_title('Reconstructed Matrix (Same Cluster Order)')

hm_cluster_err = sns.heatmap(
    err_mat_clustered,
    ax=axes_cluster[2],
    vmin=-err_abs_max,
    vmax=err_abs_max,
    cmap=shared_cmap,
    center=0,
    square=True,
    cbar_kws={'label': 'Error'},
)
axes_cluster[2].set_title('Error Matrix (Same Cluster Order)')

cbar_cluster = hm_cluster_err.collections[0].colorbar
cbar_cluster.set_ticks([-err_abs_max, 0, err_abs_max])
cbar_cluster.set_ticklabels([f'{-err_abs_max:.4f}', '0.0000', f'{err_abs_max:.4f}'])

for ax in axes_cluster:
    ax.set_xlabel('Assets (clustered)')
    ax.set_ylabel('Assets (clustered)')
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout()
path_cluster_all = heatmap_dir / 'linear_AE_clustered_heatmaps.png'
fig_cluster.savefig(path_cluster_all, dpi=150, bbox_inches='tight')
plt.show()

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

sns.heatmap(orig_mat, ax=axes[0], vmin=-1, vmax=1, cmap=shared_cmap, square=True)
axes[0].set_title('Original Matrix (No Clustering)')

sns.heatmap(recon_mat, ax=axes[1], vmin=-1, vmax=1, cmap=shared_cmap, square=True)
axes[1].set_title('Reconstructed Matrix (No Clustering)')

hm = sns.heatmap(
    err_mat,
    ax=axes[2],
    vmin=-err_abs_max,
    vmax=err_abs_max,
    cmap=shared_cmap,
    center=0,
    square=True,
    cbar_kws={'label': 'Error'},
)
axes[2].set_title('Error Matrix (No Clustering)')

cbar_std = hm.collections[0].colorbar
cbar_std.set_ticks([-err_abs_max, 0, err_abs_max])
cbar_std.set_ticklabels([f'{-err_abs_max:.4f}', '0.0000', f'{err_abs_max:.4f}'])

for ax in axes:
    ax.set_xlabel('Assets')
    ax.set_ylabel('Assets')
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout()
path_standard = heatmap_dir / 'linear_AE_standard_heatmaps.png'
fig.savefig(path_standard, dpi=150, bbox_inches='tight')
plt.show()

print(f'Saved heatmaps for matrix index {SAMPLE_IDX}:')
print(f' - {path_cluster_all}')
print(f' - {path_standard}')
# Out:
# Original Matrix:
# [[1.     0.3398 0.3781 0.309  0.5604]
#  [0.3398 1.     0.2909 0.5142 0.4363]
#  [0.3781 0.2909 1.     0.2982 0.3681]
#  [0.309  0.5142 0.2982 1.     0.4061]
#  [0.5604 0.4363 0.3681 0.4061 1.    ]]
# Reconstructed Matrix:
# [[1.201  0.2744 0.2516 0.3018 0.5277]
#  [0.2723 1.3035 0.2326 0.4808 0.4594]
#  [0.3171 0.2247 1.1508 0.2338 0.2978]
#  [0.3048 0.4426 0.3097 1.1147 0.3189]
#  [0.5007 0.3465 0.3394 0.4198 1.222 ]]
# Error Matrix:
# [[ 0.201  -0.0654 -0.1265 -0.0072 -0.0327]
#  [-0.0675  0.3035 -0.0583 -0.0335  0.0231]
#  [-0.061  -0.0662  0.1508 -0.0645 -0.0703]
#  [-0.0042 -0.0717  0.0115  0.1147 -0.0871]
#  [-0.0596 -0.0898 -0.0287  0.0137  0.222 ]]
# Sample index: 0
# MSE: 0.007816 | MAE: 0.070054 | Frobenius: 32.004635
# Error range - Min: -0.355891 | Max: 0.401629
# Saved heatmaps for matrix index 0:
#  - /content/drive/MyDrive/best_models_tesi/linearAE/linearAE_005/heatmaps/idx0/linear_AE_clustered_heatmaps.png
#  - /content/drive/MyDrive/best_models_tesi/linearAE/linearAE_005/heatmaps/idx0/linear_AE_standard_heatmaps.png

# %% [markdown]
# ## Step 7: Reconstruction Error Statistics
# Compute error statistics on the test set (MSE, MAE, Frobenius norm).

# %%
# Compute error statistics on test set only
recon_corr_test = recon_corr

errors_df, errors_stats = reconstruction_errors(test_np, recon_corr_test)

print('Reconstruction error statistics (Test Set):')
display(errors_stats)
# Out:
# Reconstruction error statistics (Test Set):
#                 mean       std        min     median        max
# MSE         0.008139  0.002188   0.004526   0.007816   0.013272
# MAE         0.070151  0.009197   0.052948   0.069432   0.088919
# Frobenius  32.374531  4.347870  24.352936  32.004635  41.703457

# %%
results_path = run_output_dir / f'linear_AE_results_{RUN}.json'

recon_stats_payload = None
if 'errors_stats' in globals():
    recon_stats_payload = errors_stats.astype(float).to_dict()

scheduler_key = str(SCHEDULER_NAME).strip().lower()
scheduler_label_map = {
    'none': None,
    'cosine': 'CosineAnnealingLR',
    'step': 'StepLR',
    'plateau': 'ReduceLROnPlateau',
}

scheduler_payload = {
    'key': scheduler_key,
    'type': scheduler_label_map.get(scheduler_key, 'Unknown'),
    'enabled': scheduler_key != 'none',
}

if scheduler_key == 'cosine':
    scheduler_payload.update({
        'T_max': int(COSINE_T_MAX),
        'eta_min': float(COSINE_ETA_MIN),
    })
elif scheduler_key == 'step':
    scheduler_payload.update({
        'step_size': int(STEP_SIZE),
        'gamma': float(STEP_GAMMA),
    })
elif scheduler_key == 'plateau':
    scheduler_payload.update({
        'factor': float(PLATEAU_FACTOR),
        'patience': int(PLATEAU_PATIENCE),
        'threshold': float(PLATEAU_THRESHOLD),
        'min_lr': float(PLATEAU_MIN_LR),
    })

results_payload = {
    'run': RUN,
    'dataset_name': DATASET_NAME,
    'dataset_dir': str(dataset_dir),
    'data': {
        'n_matrices': int(n_matrices),
        'n_assets': int(n_assets),
        'n_features': int(n_features),
        'splits': {
            'train_size': int(n_train),
            'val_size': int(n_val),
            'test_size': int(n_test),
            'val_fraction': float(VAL_FRACTION),
            'test_fraction': float(TEST_FRACTION),
        },
    },
    'model': {
        'latent_dim': int(LATENT_DIM),
        'epochs': int(EPOCHS),
        'batch_size': int(BATCH_SIZE),
        'lr': float(LR),
        'weight_decay': float(WEIGHT_DECAY),
        'seed': int(SEED),
        'scheduler': scheduler_payload,
        'best_val_loss': float(best_val) if 'best_val' in globals() else None,
        'resume': {
            'enabled': bool(RESUME_TRAINING),
            'source_model_path': str(resume_source_path) if resume_source_path is not None else None,
            'initial_best_val': float(resume_initial_val) if resume_initial_val is not None else None,
        },
    },
    'artifacts': {
        'best_model_path': str(best_model_path) if 'best_model_path' in globals() else None,
        'training_curve_path': str(train_curve_path) if 'train_curve_path' in globals() else None,
    },
    'metrics': {
        'reconstruction_stats_test': recon_stats_payload,
    },
    'loss_history': {
        'train_loss': [float(x) for x in history['train_loss']],
        'val_loss': [float(x) for x in history['val_loss']],
        'lr': [float(x) for x in history['lr']] if 'lr' in history else None,
    },
}

with open(results_path, 'w', encoding='utf-8') as f:
    json.dump(results_payload, f, indent=4)

print(f'Saved results: {results_path}')
# Out:
# Saved results: /content/drive/MyDrive/best_models_tesi/linearAE/linearAE_005/linear_AE_results_linearAE_005.json
