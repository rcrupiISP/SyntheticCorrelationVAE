# %% [markdown]
# # Data Extraction from Compressed CSV
#
# This notebook extracts data from the compressed `data.csv.gz` file and saves the processed data to the `data/processed` directory.

# %% [markdown]
# ## 1. Import Required Libraries

# %%
import pandas as pd
import os
from pathlib import Path

# %% [markdown]
# ## 2. Load Compressed CSV File
#
# Pandas automatically handles gzip compression when reading files with the `.gz` extension.

# %%
# Define the path to the compressed CSV file
FILE_NAME = 'data_10_24'
file_path = f'../data/raw/{FILE_NAME}.csv.gz'

# Read the compressed CSV file
df = pd.read_csv(file_path)

print(f"Data loaded successfully!")
print(f"Total rows: {len(df)}")
print(f"Total columns: {len(df.columns)}")

df.rename(columns={df.columns[0]: 'timestamp'}, inplace=True)
df['timestamp'] = pd.to_datetime(df['timestamp'],format='%Y-%m-%d')
# Out:
# Data loaded successfully!
# Total rows: 3768
# Total columns: 503

# %% [markdown]
# ## 3. Explore Data Structure
#
# Let's examine the first rows and get information about the dataset.

# %%
# Display first few rows
print("First 5 rows:")
print(df.head())
# Out:
# First 5 rows:
#    timestamp   A  AAPL  ABBV  ABNB        ABT  ACGL  ACN  ADBE  ADI  ...  \
# 0 2010-01-04 NaN   NaN   NaN   NaN  18.763718   NaN  NaN   NaN  NaN  ...
# 1 2010-01-05 NaN   NaN   NaN   NaN  18.612118   NaN  NaN   NaN  NaN  ...
# 2 2010-01-06 NaN   NaN   NaN   NaN  18.715481   NaN  NaN   NaN  NaN  ...
# 3 2010-01-07 NaN   NaN   NaN   NaN  18.870522   NaN  NaN   NaN  NaN  ...
# 4 2010-01-08 NaN   NaN   NaN   NaN  18.966991   NaN  NaN   NaN  NaN  ...
#
#          WTW  WY  WYNN  XEL  XOM  XYL  YUM  ZBH  ZBRA  ZTS
# 0  52.549011 NaN   NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 1  52.431255 NaN   NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 2  53.275311 NaN   NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 3  53.118282 NaN   NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 4  53.059380 NaN   NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
#
# [5 rows x 503 columns]

# %%
# Get data info
print("\nDataset Info:")
df.info()
# Out:
# Dataset Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 3768 entries, 0 to 3767
# Columns: 503 entries, timestamp to ZTS
# dtypes: datetime64[us](1), float64(502)
# memory usage: 14.5 MB

# %%
# Get statistical summary
print("\nStatistical Summary:")
print(df.describe())
# Out:
# Statistical Summary:
#                         timestamp    A  AAPL         ABBV  ABNB          ABT  \
# count                        3768  0.0   0.0  3014.000000   0.0  3768.000000
# mean   2017-06-27 13:11:27.898089  NaN   NaN    80.037153   NaN    59.315598
# min           2010-01-04 00:00:00  NaN   NaN    20.760809   NaN    16.050135
# 25%           2013-09-30 18:00:00  NaN   NaN    42.954745   NaN    29.604751
# 50%           2017-06-27 12:00:00  NaN   NaN    68.253288   NaN    42.686844
# 75%           2021-03-25 06:00:00  NaN   NaN   117.794596   NaN    98.894169
# max           2024-12-20 00:00:00  NaN   NaN   203.869995   NaN   133.728134
# std                           NaN  NaN   NaN    45.771217   NaN    35.234615
#
#        ACGL  ACN  ADBE  ADI  ...          WTW   WY  WYNN  XEL  XOM  \
# count   0.0  0.0   0.0  0.0  ...  3768.000000  0.0   0.0  0.0  0.0
# mean    NaN  NaN   NaN  NaN  ...   144.717425  NaN   NaN  NaN  NaN
# min     NaN  NaN   NaN  NaN  ...    51.390854  NaN   NaN  NaN  NaN
# 25%     NaN  NaN   NaN  NaN  ...    91.976917  NaN   NaN  NaN  NaN
# 50%     NaN  NaN   NaN  NaN  ...   130.360306  NaN   NaN  NaN  NaN
# 75%     NaN  NaN   NaN  NaN  ...   199.082058  NaN   NaN  NaN  NaN
# max     NaN  NaN   NaN  NaN  ...   332.529999  NaN   NaN  NaN  NaN
# std     NaN  NaN   NaN  NaN  ...    64.574906  NaN   NaN  NaN  NaN
#
#                XYL  YUM  ZBH  ZBRA  ZTS
# count  3319.000000  0.0  0.0   0.0  0.0
# mean     64.613543  NaN  NaN   NaN  NaN
# min      19.335064  NaN  NaN   NaN  NaN
# 25%      32.083246  NaN  NaN   NaN  NaN
# 50%      63.070297  NaN  NaN   NaN  NaN
# 75%      92.678478  NaN  NaN   NaN  NaN
# max     144.777908  NaN  NaN   NaN  NaN
# std      34.711638  NaN  NaN   NaN  NaN
#
# [8 rows x 503 columns]

# %% [markdown]
# ## 4. Save Processed Data
#
# Create the output directory if it doesn't exist and save the extracted data as CSV.

# %%
# Define the output directory
output_dir = Path('../data/processed')

# Create the directory if it doesn't exist
output_dir.mkdir(parents=True, exist_ok=True)

# Save the data as CSV
output_path = output_dir / f'{FILE_NAME}.csv'
df.to_csv(output_path, index=False)

print(f"Data saved to: {output_path}")
print(f"File size: {os.path.getsize(output_path) / (1024*1024):.2f} MB")
# Out:
# Data saved to: ..\data\processed\data_10_24.csv
# File size: 11.93 MB
