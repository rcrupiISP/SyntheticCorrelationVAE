# %% [markdown]
# # Data Extraction from Compressed CSV
#
# This notebook extracts data from the compressed `data.csv.gz` file and saves the processed data to the `data/processed` directory.

# %% [markdown]
# ## 1. Import Required Libraries

# %%
import pandas as pd
import os
from pathlib import Path

# %% [markdown]
# ## 2. Load Compressed CSV File
#
# Pandas automatically handles gzip compression when reading files with the `.gz` extension.

# %%
# Define the path to the compressed CSV file
file_path = '../data/raw/data.csv.gz'

# Read the compressed CSV file
df = pd.read_csv(file_path)

print(f"Data loaded successfully!")
print(f"Total rows: {len(df)}")
print(f"Total columns: {len(df.columns)}")
# Out:
# Data loaded successfully!
# Total rows: 1260
# Total columns: 640

# %% [markdown]
# ## 3. Explore Data Structure
#
# Let's examine the first rows and get information about the dataset.

# %%
# Display first few rows
print("First 5 rows:")
print(df.head())
# Out:
# First 5 rows:
#          BBY        GME  RF  LIFE       CSCO  REG        TSN        TEG  \
# 0  14.313087  20.399103 NaN   NaN  17.893888  NaN  21.696400  51.308858
# 1  14.967250  19.800806 NaN   NaN  17.872437  NaN  22.184497  50.882569
# 2  15.499302  19.380913 NaN   NaN  17.795216  NaN  22.213208  51.063969
# 3  16.048799  20.006635 NaN   NaN  18.205347  NaN  22.328055  51.816777
# 4  16.354075  20.097200 NaN   NaN  18.631780  NaN  22.557748  51.317928
#
#          KMI       LDOS  ...        COH        MSI    RHT  TPR  SPGI  DXC  \
# 0  30.784206  19.144100  ...  41.309043  56.243199  50.81  NaN   NaN  NaN
# 1  30.941988  19.387045  ...  41.215023  56.080464  51.58  NaN   NaN  NaN
# 2  31.174510  19.403241  ...  42.121035  56.505384  52.08  NaN   NaN  NaN
# 3  31.108075  19.403241  ...  42.821913  56.930305  51.99  NaN   NaN  NaN
# 4  30.701162  19.516616  ...  42.933027  57.056877  52.80  NaN   NaN  NaN
#
#           DD        VMC  NWS  ULTA
# 0  40.617748  49.740070  NaN   NaN
# 1  40.778863  50.775304  NaN   NaN
# 2  40.965416  50.882734  NaN   NaN
# 3  41.279165  52.435585  NaN   NaN
# 4  41.330043  52.250024  NaN   NaN
#
# [5 rows x 640 columns]

# %%
# Get data info
print("\nDataset Info:")
df.info()
# Out:
# Dataset Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Columns: 640 entries, BBY to ULTA
# dtypes: float64(640)
# memory usage: 6.2 MB

# %%
# Get statistical summary
print("\nStatistical Summary:")
print(df.describe())
# Out:
# Statistical Summary:
#                BBY         GME          RF  LIFE         CSCO         REG  \
# count  1258.000000  798.000000  985.000000   0.0  1258.000000  228.000000
# mean     36.354688   34.209938   11.098076   NaN    26.159047   63.756280
# std      12.528227    5.680991    2.992707   NaN     5.482934    3.006950
# min      14.313087   19.380913    6.792908   NaN    17.627618   55.580000
# 25%      28.343349   30.376785    9.066805   NaN    21.895651   61.883326
# 50%      32.463303   34.652269    9.613522   NaN    25.630750   63.915000
# 75%      41.953875   38.205282   14.011584   NaN    29.717577   65.797580
# max      78.060000   48.067639   19.800000   NaN    45.360000   70.370000
#
#                TSN         TEG          KMI        LDOS  ...          COH  \
# count  1258.000000  588.000000  1258.000000  148.000000  ...  1178.000000
# mean     49.010186   60.983585    26.283285   24.443236  ...    38.252361
# std      16.669974    9.085335     7.399718    2.350724  ...     6.415091
# min      21.696400   49.144202    11.399810   19.144100  ...    25.583129
# 25%      37.224988   52.880260    19.248713   23.009050  ...    33.221552
# 50%      42.102828   56.979169    28.049532   24.476180  ...    37.507445
# 75%      63.766883   70.359405    32.158098   26.443587  ...    43.296656
# max      83.620000   81.617607    40.507330   28.349152  ...    51.505108
#
#                MSI          RHT        TPR        SPGI         DXC  \
# count  1258.000000  1258.000000  80.000000  460.000000  209.000000
# mean     67.830893    73.157456  44.814750  136.186118   87.514520
# std      12.736192    21.369796   3.383934   23.058805    8.955179
# min      49.260343    42.350000  40.160000   97.683176   73.800209
# 25%      58.210268    56.150000  41.622500  118.427827   78.242165
# 50%      62.662219    72.920000  44.800000  129.335040   85.194876
# 75%      77.604678    79.725000  47.550000  153.791579   95.804313
# max     106.820000   148.030000  51.160000  193.300000  104.640000
#
#                 DD          VMC         NWS        ULTA
# count  1137.000000  1258.000000  606.000000  460.000000
# mean     61.654951    88.962709   13.478509  248.070165
# std      10.298615    28.495249    1.474873   28.302121
# min      40.617748    44.524834   10.562627  190.160000
# 25%      54.116544    61.451594   12.457721  226.375000
# 50%      61.598149    89.499742   13.363275  247.530000
# 75%      67.183220   117.276250   14.000000  270.310000
# max      85.107674   141.110000   17.550000  313.730000
#
# [8 rows x 640 columns]

# %% [markdown]
# ## 4. Save Processed Data
#
# Create the output directory if it doesn't exist and save the extracted data as CSV.

# %%
# Define the output directory
output_dir = Path('../data/processed')

# Create the directory if it doesn't exist
output_dir.mkdir(parents=True, exist_ok=True)

# Save the data as CSV
output_path = output_dir / 'data.csv'
df.to_csv(output_path, index=False)

print(f"Data saved to: {output_path}")
print(f"File size: {os.path.getsize(output_path) / (1024*1024):.2f} MB")
# Out:
# Data saved to: ..\data\processed\data.csv
# File size: 8.57 MB
